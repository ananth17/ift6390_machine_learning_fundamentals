# %%
import theano.tensor as T
from theano import function

# define variables to add
# dscalar is a theano type:
# - scalar = 0-dmensional array
# - double precision
x = T.dscalar('x')
y = T.dscalar('y')

# 
z = x + y

# f will be compiled to C code
f = function([x,y], z)

# %%
f(2,3)
# Out:
# array(5.0)

# %%
type(x)
# Out:
# theano.tensor.var.TensorVariable

# %% [markdown]
# ## Matrix additions

# %%
x = T.dmatrix('x')
y = T.dmatrix('y')
z = x + y
f = function([x, y], z)

# %%
f([[1,2],[3,4]], [[5,6],[7,8]])
# Out:
# array([[  6.,   8.],
#        [ 10.,  12.]])

# %%
a = T.vector()
b = T.vector()
out = (a ** 2) + (b ** 2) + (2 * a * b)
f = function([a, b], out)
f([1,2], [4,5])
# Out:
# array([ 25.,  49.])

# %% [markdown]
# ## Logistic function

# %%
x = T.dmatrix('x')
# this is the equation of the logistic equation
s = 1 / (1 + T.exp(-x))
logistic = function([x], s)
logistic([[0, 1], [-1, -2]])
# Out:
# array([[ 0.5       ,  0.73105858],
#        [ 0.26894142,  0.11920292]])

# %%
# apparently, logistic equation is equivalent to this one
s2 = (1 + T.tanh(x / 2)) / 2
logistic2 = function([x], s2)
logistic2([[0, 1], [-1, -2]])
# Out:
# array([[ 0.5       ,  0.73105858],
#        [ 0.26894142,  0.11920292]])

# %%
# let's try matrix abs diff and squared diff

x, y = T.dmatrices('x', 'y')

abs_diff = abs(x - y)
squared_diff = (x - y) * (x - y)
f = function([x,y], [abs_diff, squared_diff])

f([[1,2],[3,4]], [[4,3],[2,1]])
# Out:
# [array([[ 3.,  1.],
#         [ 1.,  3.]]), array([[ 9.,  1.],
#         [ 1.,  9.]])]

# %% [markdown]
# ## Default values and named arguments

# %%
# set default values in the function declaration
from theano import Param
x, y = T.dscalars('x', 'y')
z = x + (y/2-12)
f = function([Param(x, name='x'), Param(y, default=42, name='y')], z)
print f(33)
print f(33, 42)
print(f(y=42, x=33))
# Out:
# 42.0
# 42.0
# 42.0

# %% [markdown]
# ## Shared variables

# %%
# used to make an accumulator for example, could be thought as a class variable in Java I think
from theano import shared
state = shared(0)
inc = T.iscalar('inc') # integer scalar
accumulator = function([inc], state, updates=[(state, state+inc)])

accumulator(0)
accumulator(200)
state.get_value()
# Out:
# array(200)

# %% [markdown]
# ## Random numbers

# %%
# random stream interface as in ssj
from theano.tensor.shared_randomstreams import RandomStreams
from theano import function
srng = RandomStreams()

rv_u = srng.uniform((2,2))
rv_n = srng.normal((2,2))
f = function([], rv_u)
g = function([], rv_n, no_default_updates=True) # no update to rv_n.rng
nearly_zeros = function([], rv_u + rv_u - 2 * rv_u)

# %% [markdown]
# ## Logistic regression

# %%
import numpy
import theano
import theano.tensor as T
rng = numpy.random

N = 400
feats = 784
D = (rng.randn(N, feats), rng.randint(size=N, low=0, high=2))
training_steps = 10000

# declare theano symbolic variables
# observations (x,y), it's supervised learning...
x = T.matrix('x')
y = T.vector('y')
# weights and biases
w = theano.shared(rng.randn(feats), name='w')
b = theano.shared(0., name="b")

print "Initial model:"
print w.get_value(), b.get_value()

# construct theano expression graph (will have to dig deeper on the meaning of expresison graph)
# could be simply an AST?
# actually, it's the way mathematical expressions are symbolically represented internally...

# Construct Theano expression graph
p_1 = 1 / (1 + T.exp(-T.dot(x, w) - b))   # Probability that target = 1
prediction = p_1 > 0.5                    # The prediction thresholded
xent = -y * T.log(p_1) - (1-y) * T.log(1-p_1) # Cross-entropy loss function
cost = xent.mean() + 0.01 * (w ** 2).sum()# The cost to minimize
gw, gb = T.grad(cost, [w, b])             # Compute the gradient of the cost
                                          # (we shall return to this in a
                                          # following section of this tutorial)

# Compile
train = theano.function(
          inputs=[x,y],
          outputs=[prediction, xent],
          updates=((w, w - 0.1 * gw), (b, b - 0.1 * gb)))
predict = theano.function(inputs=[x], outputs=prediction)

# Train
for i in range(training_steps):
    pred, err = train(D[0], D[1])

print "Final model:"
print w.get_value(), b.get_value()
print "target values for D:", D[1]
print "prediction on D:", predict(D[0])
# Out:
# Initial model:
# [ -7.37706123e-01  -4.17507546e-01  -1.61494266e+00  -6.86723343e-01
#   -8.18062819e-01  -1.67008619e+00  -8.28659097e-02   2.40951596e-01
#    1.43805620e-01  -1.44388967e+00  -2.62684940e-01  -1.55528266e-01
#    1.40426558e+00   1.22310928e+00  -1.15946620e+00  -1.10614038e+00
#   -3.58590678e-01   5.91611388e-01   5.32021227e-01  -1.06788960e+00
#   -2.04206637e-02   3.83117794e-01  -4.12122007e+00   2.80505191e-01
#   -8.42387805e-01  -2.09214707e+00   4.98409487e-01  -1.79394655e+00
#   -2.78059964e-01   8.26025394e-01  -6.53307088e-01   8.74334040e-01
#   -1.39473851e-01  -1.11631659e+00  -8.51769373e-02   7.08860121e-01
#    1.32553997e+00  -1.11849682e+00  -2.25004190e+00  -2.84231642e-01
#    6.50702659e-01  -6.72504778e-02  -7.99230697e-01  -7.21545022e-01
#   -1.03461295e+00  -1.42812853e+00  -1.58625251e+00  -9.57786019e-01
#    1.04356257e+00   8.20174124e-01  -4.58509671e-01   7.13605858e-01
#   -7.31699117e-01  -1.32525814e+00   7.74651209e-01   9.50317652e-01
#    4.52497000e-01   8.52800083e-01  -9.68267136e-01   1.31639923e-01
#    1.50010320e+00   2.50180095e-01  -1.28505271e+00  -7.08163304e-01
#    1.21056841e+00   4.19073098e-01  -2.67082055e-01   7.21718308e-01
#    2.61815972e-01   1.58079932e+00   3.34406791e-01  -3.90228454e-01
#    1.79860276e+00  -2.56771678e+00   1.34490166e+00  -9.04465022e-02
#    1.06561238e+00  -1.51659751e-01  -1.56417505e+00   1.22130075e-01
#    1.51258164e+00  -2.05272859e-01  -5.78471759e-01   1.67306904e+00
#    3.92019711e-02   8.23571616e-01   1.39414277e-01  -4.87452254e-01
#    9.52304520e-01  -4.90832924e-01  -3.41000536e-02   1.94365699e-01
#    2.03115002e-01  -2.31352490e-01   1.13925331e+00   2.30543647e+00
#   -1.44577319e+00   6.89520879e-01   1.07929102e+00  -1.51436119e+00
#    6.72449777e-01   2.17576993e-02   8.83811142e-02  -6.24058787e-01
#   -7.46896419e-01  -1.08905234e+00  -7.91122416e-01   1.53437055e+00
#    2.21427874e+00   9.25178156e-01  -6.80453612e-01   5.25370215e-01
#   -1.59604205e+00  -2.18952857e+00  -7.25274007e-01   5.55775357e-01
#    2.10815995e+00  -1.13521601e+00   6.03396095e-01  -2.35506781e-01
#   -4.54906076e-02   2.74295630e-01  -9.75717012e-01  -1.42728698e+00
#    8.27963801e-01   8.79493453e-01   1.23348241e+00  -3.21680095e-01
#    1.19971824e+00  -4.70414735e-01   1.03438533e-01   1.65628247e+00
#    1.56114021e+00   2.03018222e-01  -5.69841635e-01   7.92354912e-01
#   -3.50778212e-01  -2.34892872e+00  -2.21703220e+00   6.16897671e-01
#    2.04257189e+00   1.47001842e+00  -1.69338670e+00  -2.42086192e-01
#   -8.79265470e-01   8.45888595e-01  -1.19980531e+00  -9.49164433e-01
#    2.30028370e-01   2.12883347e-01  -3.12571520e-01  -6.74513326e-01
#    1.04390316e+00   2.42940074e-01   5.76790532e-01  -1.50748336e+00
#   -3.37894872e-03  -1.40339365e+00   8.07713033e-01   6.20150932e-01] 0.0
# ===============================
# ===============================
# /usr/bin/ld: cannot find -lf77blas
# /usr/bin/ld: cannot find -lcblas
# /usr/bin/ld: cannot find -latlas
# collect2: error: ld returned 1 exit status
# 00001	#include <Python.h>
# 00002	#include <iostream>
# 00003	#include <math.h>
# 00004	#include <numpy/arrayobject.h>
# 00005	#include <numpy/arrayscalars.h>
# 00006	//////////////////////
# 00007	////  Support Code
# 00008	//////////////////////
# 00009
# 00010
# 00011	    extern "C"
# 00012	    {
# 00013
# 00014	        void xerbla_(char*, void *);
# 00015
# 00016	    /***********/
# 00017	    /* Level 1 */
# 00018	    /***********/
# 00019
# 00020	    /* Single Precision */
# 00021
# 00022	        void srot_(const int*, float *, const int*, float *, const int*, const float *, const float *);
# 00023	        void srotg_(float *,float *,float *,float *);
# 00024	        void srotm_( const int*, float *, const int*, float *, const int*, const float *);
# 00025	        void srotmg_(float *,float *,float *,const float *, float *);
# 00026	        void sswap_( const int*, float *, const int*, float *, const int*);
# 00027	        void scopy_( const int*, const float *, const int*, float *, const int*);
# 00028	        void saxpy_( const int*, const float *, const float *, const int*, float *, const int*);
# 00029	        float sdot_(const int*, const float *, const int*, const float *, const int*);
# 00030	        void sdot_sub_(const int*, const float *, const int*, const float *, const int*, float *);
# 00031	        void sdsdot_sub_( const int*, const float *, const float *, const int*, const float *, const int*, float *);
# 00032	        void sscal_( const int*, const float *, float *, const int*);
# 00033	        void snrm2_sub_( const int*, const float *, const int*, float *);
# 00034	        void sasum_sub_( const int*, const float *, const int*, float *);
# 00035	        void isamax_sub_( const int*, const float * , const int*, const int*);
# 00036
# 00037	    /* Double Precision */
# 00038
# 00039	        void drot_(const int*, double *, const int*, double *, const int*, const double *, const double *);
# 00040	        void drotg_(double *,double *,double *,double *);
# 00041	        void drotm_( const int*, double *, const int*, double *, const int*, const double *);
# 00042	        void drotmg_(double *,double *,double *,const double *, double *);
# 00043	        void dswap_( const int*, double *, const int*, double *, const int*);
# 00044	        void dcopy_( const int*, const double *, const int*, double *, const int*);
# 00045	        void daxpy_( const int*, const double *, const double *, const int*, double *, const int*);
# 00046	        void dswap_( const int*, double *, const int*, double *, const int*);
# 00047	        double ddot_(const int*, const double *, const int*, const double *, const int*);
# 00048	        void dsdot_sub_(const int*, const float *, const int*, const float *, const int*, double *);
# 00049	        void ddot_sub_( const int*, const double *, const int*, const double *, const int*, double *);
# 00050	        void dscal_( const int*, const double *, double *, const int*);
# 00051	        void dnrm2_sub_( const int*, const double *, const int*, double *);
# 00052	        void dasum_sub_( const int*, const double *, const int*, double *);
# 00053	        void idamax_sub_( const int*, const double * , const int*, const int*);
# 00054
# 00055	    /* Single Complex Precision */
# 00056
# 00057	        void cswap_( const int*, void *, const int*, void *, const int*);
# 00058	        void ccopy_( const int*, const void *, const int*, void *, const int*);
# 00059	        void caxpy_( const int*, const void *, const void *, const int*, void *, const int*);
# 00060	        void cswap_( const int*, void *, const int*, void *, const int*);
# 00061	        void cdotc_sub_( const int*, const void *, const int*, const void *, const int*, void *);
# 00062	        void cdotu_sub_( const int*, const void *, const int*, const void *, const int*, void *);
# 00063	        void cscal_( const int*, const void *, void *, const int*);
# 00064	        void icamax_sub_( const int*, const void *, const int*, const int*);
# 00065	        void csscal_( const int*, const float *, void *, const int*);
# 00066	        void scnrm2_sub_( const int*, const void *, const int*, float *);
# 00067	        void scasum_sub_( const int*, const void *, const int*, float *);
# 00068
# 00069	    /* Double Complex Precision */
# 00070
# 00071	        void zswap_( const int*, void *, const int*, void *, const int*);
# 00072	        void zcopy_( const int*, const void *, const int*, void *, const int*);
# 00073	        void zaxpy_( const int*, const void *, const void *, const int*, void *, const int*);
# 00074	        void zswap_( const int*, void *, const int*, void *, const int*);
# 00075	        void zdotc_sub_( const int*, const void *, const int*, const void *, const int*, void *);
# 00076	        void zdotu_sub_( const int*, const void *, const int*, const void *, const int*, void *);
# 00077	        void zdscal_( const int*, const double *, void *, const int*);
# 00078	        void zscal_( const int*, const void *, void *, const int*);
# 00079	        void dznrm2_sub_( const int*, const void *, const int*, double *);
# 00080	        void dzasum_sub_( const int*, const void *, const int*, double *);
# 00081	        void izamax_sub_( const int*, const void *, const int*, const int*);
# 00082
# 00083	    /***********/
# 00084	    /* Level 2 */
# 00085	    /***********/
# 00086
# 00087	    /* Single Precision */
# 00088
# 00089	        void sgemv_(char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00090	        void sgbmv_(char*, const int*, const int*, const int*, const int*, const float *,  const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00091	        void ssymv_(char*, const int*, const float *, const float *, const int*, const float *,  const int*, const float *, float *, const int*);
# 00092	        void ssbmv_(char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00093	        void sspmv_(char*, const int*, const float *, const float *, const float *, const int*, const float *, float *, const int*);
# 00094	        void strmv_( char*, char*, char*, const int*, const float *, const int*, float *, const int*);
# 00095	        void stbmv_( char*, char*, char*, const int*, const int*, const float *, const int*, float *, const int*);
# 00096	        void strsv_( char*, char*, char*, const int*, const float *, const int*, float *, const int*);
# 00097	        void stbsv_( char*, char*, char*, const int*, const int*, const float *, const int*, float *, const int*);
# 00098	        void stpmv_( char*, char*, char*, const int*, const float *, float *, const int*);
# 00099	        void stpsv_( char*, char*, char*, const int*, const float *, float *, const int*);
# 00100	        void sger_( const int*, const int*, const float *, const float *, const int*, const float *, const int*, float *, const int*);
# 00101	        void ssyr_(char*, const int*, const float *, const float *, const int*, float *, const int*);
# 00102	        void sspr_(char*, const int*, const float *, const float *, const int*, float *);
# 00103	        void sspr2_(char*, const int*, const float *, const float *, const int*, const float *, const int*,  float *);
# 00104	        void ssyr2_(char*, const int*, const float *, const float *, const int*, const float *, const int*,  float *, const int*);
# 00105
# 00106	    /* Double Precision */
# 00107
# 00108	        void dgemv_(char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00109	        void dgbmv_(char*, const int*, const int*, const int*, const int*, const double *,  const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00110	        void dsymv_(char*, const int*, const double *, const double *, const int*, const double *,  const int*, const double *, double *, const int*);
# 00111	        void dsbmv_(char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00112	        void dspmv_(char*, const int*, const double *, const double *, const double *, const int*, const double *, double *, const int*);
# 00113	        void dtrmv_( char*, char*, char*, const int*, const double *, const int*, double *, const int*);
# 00114	        void dtbmv_( char*, char*, char*, const int*, const int*, const double *, const int*, double *, const int*);
# 00115	        void dtrsv_( char*, char*, char*, const int*, const double *, const int*, double *, const int*);
# 00116	        void dtbsv_( char*, char*, char*, const int*, const int*, const double *, const int*, double *, const int*);
# 00117	        void dtpmv_( char*, char*, char*, const int*, const double *, double *, const int*);
# 00118	        void dtpsv_( char*, char*, char*, const int*, const double *, double *, const int*);
# 00119	        void dger_( const int*, const int*, const double *, const double *, const int*, const double *, const int*, double *, const int*);
# 00120	        void dsyr_(char*, const int*, const double *, const double *, const int*, double *, const int*);
# 00121	        void dspr_(char*, const int*, const double *, const double *, const int*, double *);
# 00122	        void dspr2_(char*, const int*, const double *, const double *, const int*, const double *, const int*,  double *);
# 00123	        void dsyr2_(char*, const int*, const double *, const double *, const int*, const double *, const int*,  double *, const int*);
# 00124
# 00125	    /* Single Complex Precision */
# 00126
# 00127	        void cgemv_(char*, const int*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00128	        void cgbmv_(char*, const int*, const int*, const int*, const int*, const void *,  const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00129	        void chemv_(char*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00130	        void chbmv_(char*, const int*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00131	        void chpmv_(char*, const int*, const void *, const void *, const void *, const int*, const void *, void *, const int*);
# 00132	        void ctrmv_( char*, char*, char*, const int*, const void *, const int*, void *, const int*);
# 00133	        void ctbmv_( char*, char*, char*, const int*, const int*, const void *, const int*, void *, const int*);
# 00134	        void ctpmv_( char*, char*, char*, const int*, const void *, void *, const int*);
# 00135	        void ctrsv_( char*, char*, char*, const int*, const void *, const int*, void *, const int*);
# 00136	        void ctbsv_( char*, char*, char*, const int*, const int*, const void *, const int*, void *, const int*);
# 00137	        void ctpsv_( char*, char*, char*, const int*, const void *, void *,const int*);
# 00138	        void cgerc_( const int*, const int*, const void *, const void *, const int*, const void *, const int*, void *, const int*);
# 00139	        void cgeru_( const int*, const int*, const void *, const void *, const int*, const void *, const int*, void *,  const int*);
# 00140	        void cher_(char*, const int*, const float *, const void *, const int*, void *, const int*);
# 00141	        void cher2_(char*, const int*, const void *, const void *, const int*, const void *, const int*, void *, const int*);
# 00142	        void chpr_(char*, const int*, const float *, const void *, const int*, void *);
# 00143	        void chpr2_(char*, const int*, const float *, const void *, const int*, const void *, const int*, void *);
# 00144
# 00145	    /* Double Complex Precision */
# 00146
# 00147	        void zgemv_(char*, const int*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00148	        void zgbmv_(char*, const int*, const int*, const int*, const int*, const void *,  const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00149	        void zhemv_(char*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00150	        void zhbmv_(char*, const int*, const int*, const void *, const void *, const int*, const void *, const int*, const void *, void *, const int*);
# 00151	        void zhpmv_(char*, const int*, const void *, const void *, const void *, const int*, const void *, void *, const int*);
# 00152	        void ztrmv_( char*, char*, char*, const int*, const void *, const int*, void *, const int*);
# 00153	        void ztbmv_( char*, char*, char*, const int*, const int*, const void *, const int*, void *, const int*);
# 00154	        void ztpmv_( char*, char*, char*, const int*, const void *, void *, const int*);
# 00155	        void ztrsv_( char*, char*, char*, const int*, const void *, const int*, void *, const int*);
# 00156	        void ztbsv_( char*, char*, char*, const int*, const int*, const void *, const int*, void *, const int*);
# 00157	        void ztpsv_( char*, char*, char*, const int*, const void *, void *,const int*);
# 00158	        void zgerc_( const int*, const int*, const void *, const void *, const int*, const void *, const int*, void *, const int*);
# 00159	        void zgeru_( const int*, const int*, const void *, const void *, const int*, const void *, const int*, void *,  const int*);
# 00160	        void zher_(char*, const int*, const double *, const void *, const int*, void *, const int*);
# 00161	        void zher2_(char*, const int*, const void *, const void *, const int*, const void *, const int*, void *, const int*);
# 00162	        void zhpr_(char*, const int*, const double *, const void *, const int*, void *);
# 00163	        void zhpr2_(char*, const int*, const double *, const void *, const int*, const void *, const int*, void *);
# 00164
# 00165	    /***********/
# 00166	    /* Level 3 */
# 00167	    /***********/
# 00168
# 00169	    /* Single Precision */
# 00170
# 00171	        void sgemm_(char*, char*, const int*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00172	        void ssymm_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00173	        void ssyrk_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, float *, const int*);
# 00174	        void ssyr2k_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00175	        void strmm_(char*, char*, char*, char*, const int*, const int*, const float *, const float *, const int*, float *, const int*);
# 00176	        void strsm_(char*, char*, char*, char*, const int*, const int*, const float *, const float *, const int*, float *, const int*);
# 00177
# 00178	    /* Double Precision */
# 00179
# 00180	        void dgemm_(char*, char*, const int*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00181	        void dsymm_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00182	        void dsyrk_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, double *, const int*);
# 00183	        void dsyr2k_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00184	        void dtrmm_(char*, char*, char*, char*, const int*, const int*, const double *, const double *, const int*, double *, const int*);
# 00185	        void dtrsm_(char*, char*, char*, char*, const int*, const int*, const double *, const double *, const int*, double *, const int*);
# 00186
# 00187	    /* Single Complex Precision */
# 00188
# 00189	        void cgemm_(char*, char*, const int*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00190	        void csymm_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00191	        void chemm_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00192	        void csyrk_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, float *, const int*);
# 00193	        void cherk_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, float *, const int*);
# 00194	        void csyr2k_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00195	        void cher2k_(char*, char*, const int*, const int*, const float *, const float *, const int*, const float *, const int*, const float *, float *, const int*);
# 00196	        void ctrmm_(char*, char*, char*, char*, const int*, const int*, const float *, const float *, const int*, float *, const int*);
# 00197	        void ctrsm_(char*, char*, char*, char*, const int*, const int*, const float *, const float *, const int*, float *, const int*);
# 00198
# 00199	    /* Double Complex Precision */
# 00200
# 00201	        void zgemm_(char*, char*, const int*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00202	        void zsymm_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00203	        void zhemm_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00204	        void zsyrk_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, double *, const int*);
# 00205	        void zherk_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, double *, const int*);
# 00206	        void zsyr2k_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00207	        void zher2k_(char*, char*, const int*, const int*, const double *, const double *, const int*, const double *, const int*, const double *, double *, const int*);
# 00208	        void ztrmm_(char*, char*, char*, char*, const int*, const int*, const double *, const double *, const int*, double *, const int*);
# 00209	        void ztrsm_(char*, char*, char*, char*, const int*, const int*, const double *, const double *, const int*, double *, const int*);
# 00210
# 00211	    }
# 00212
# 00213
# 00214	    struct __struct_compiled_op_f669e97685c3ebc76359b78f6a28a991 {
# 00215	        PyObject* __ERROR;
# 00216
# 00217	        PyObject* storage_V3;
# 00218	PyObject* storage_V5;
# 00219	PyObject* storage_V7;
# 00220	PyObject* storage_V9;
# 00221	PyObject* storage_V11;
# 00222	PyObject* storage_V1;
# 00223
# 00224
# 00225	        __struct_compiled_op_f669e97685c3ebc76359b78f6a28a991() {}
# 00226	        ~__struct_compiled_op_f669e97685c3ebc76359b78f6a28a991(void) {
# 00227	            cleanup();
# 00228	        }
# 00229
# 00230	        int init(PyObject* __ERROR, PyObject* storage_V3, PyObject* storage_V5, PyObject* storage_V7, PyObject* storage_V9, PyObject* storage_V11, PyObject* storage_V1) {
# 00231	            Py_XINCREF(storage_V3);
# 00232	Py_XINCREF(storage_V5);
# 00233	Py_XINCREF(storage_V7);
# 00234	Py_XINCREF(storage_V9);
# 00235	Py_XINCREF(storage_V11);
# 00236	Py_XINCREF(storage_V1);
# 00237	            this->storage_V3 = storage_V3;
# 00238	this->storage_V5 = storage_V5;
# 00239	this->storage_V7 = storage_V7;
# 00240	this->storage_V9 = storage_V9;
# 00241	this->storage_V11 = storage_V11;
# 00242	this->storage_V1 = storage_V1;
# 00243	            int __failure = 0;
# 00244
# 00245	{
# 00246
# 00247	{
# 00248
# 00249	{
# 00250
# 00251	{
# 00252
# 00253	{
# 00254
# 00255	{
# 00256
# 00257	            this->__ERROR = __ERROR;
# 00258	            return 0;
# 00259	            __label_11:
# 00260
# 00261	double __DUMMY_11;
# 00262
# 00263	}
# 00264	__label_9:
# 00265
# 00266	double __DUMMY_9;
# 00267
# 00268	}
# 00269	__label_7:
# 00270
# 00271	double __DUMMY_7;
# 00272
# 00273	}
# 00274	__label_5:
# 00275
# 00276	double __DUMMY_5;
# 00277
# 00278	}
# 00279	__label_3:
# 00280
# 00281	double __DUMMY_3;
# 00282
# 00283	}
# 00284	__label_1:
# 00285
# 00286	double __DUMMY_1;
# 00287
# 00288	}
# 00289
# 00290	            Py_XDECREF(this->storage_V3);
# 00291	Py_XDECREF(this->storage_V5);
# 00292	Py_XDECREF(this->storage_V7);
# 00293	Py_XDECREF(this->storage_V9);
# 00294	Py_XDECREF(this->storage_V11);
# 00295	Py_XDECREF(this->storage_V1);
# 00296
# 00297	        if (__failure) {
# 00298	            // When there is a failure, this code puts the exception
# 00299	            // in __ERROR.
# 00300	            PyObject* err_type = NULL;
# 00301	            PyObject* err_msg = NULL;
# 00302	            PyObject* err_traceback = NULL;
# 00303	            PyErr_Fetch(&err_type, &err_msg, &err_traceback);
# 00304	            if (!err_type) {err_type = Py_None;Py_INCREF(Py_None);}
# 00305	            if (!err_msg) {err_msg = Py_None; Py_INCREF(Py_None);}
# 00306	            if (!err_traceback) {err_traceback = Py_None; Py_INCREF(Py_None);}
# 00307	            PyObject* old_err_type = PyList_GET_ITEM(__ERROR, 0);
# 00308	            PyObject* old_err_msg = PyList_GET_ITEM(__ERROR, 1);
# 00309	            PyObject* old_err_traceback = PyList_GET_ITEM(__ERROR, 2);
# 00310	            PyList_SET_ITEM(__ERROR, 0, err_type);
# 00311	            PyList_SET_ITEM(__ERROR, 1, err_msg);
# 00312	            PyList_SET_ITEM(__ERROR, 2, err_traceback);
# 00313	            {Py_XDECREF(old_err_type);}
# 00314	            {Py_XDECREF(old_err_msg);}
# 00315	            {Py_XDECREF(old_err_traceback);}
# 00316	        }
# 00317	        // The failure code is returned to index what code block failed.
# 00318	        return __failure;
# 00319
# 00320	        }
# 00321	        void cleanup(void) {
# 00322	            __label_1:
# 00323
# 00324	double __DUMMY_1;
# 00325	__label_3:
# 00326
# 00327	double __DUMMY_3;
# 00328	__label_5:
# 00329
# 00330	double __DUMMY_5;
# 00331	__label_7:
# 00332
# 00333	double __DUMMY_7;
# 00334	__label_9:
# 00335
# 00336	double __DUMMY_9;
# 00337	__label_11:
# 00338
# 00339	double __DUMMY_11;
# 00340
# 00341	            Py_XDECREF(this->storage_V3);
# 00342	Py_XDECREF(this->storage_V5);
# 00343	Py_XDECREF(this->storage_V7);
# 00344	Py_XDECREF(this->storage_V9);
# 00345	Py_XDECREF(this->storage_V11);
# 00346	Py_XDECREF(this->storage_V1);
# 00347	        }
# 00348	        int run(void) {
# 00349	            int __failure = 0;
# 00350
# 00351	    PyObject* py_V1;
# 00352
# 00353	        PyArrayObject* V1;
# 00354	        int type_num_V1;
# 00355	        typedef npy_float64 dtype_V1;
# 00356
# 00357	    PyObject* py_V3;
# 00358
# 00359	        PyArrayObject* V3;
# 00360	        int type_num_V3;
# 00361	        typedef npy_float64 dtype_V3;
# 00362
# 00363	    PyObject* py_V5;
# 00364
# 00365	        PyArrayObject* V5;
# 00366	        int type_num_V5;
# 00367	        typedef npy_float64 dtype_V5;
# 00368
# 00369	    PyObject* py_V7;
# 00370
# 00371	        PyArrayObject* V7;
# 00372	        int type_num_V7;
# 00373	        typedef npy_float64 dtype_V7;
# 00374
# 00375	    PyObject* py_V9;
# 00376
# 00377	        PyArrayObject* V9;
# 00378	        int type_num_V9;
# 00379	        typedef npy_float64 dtype_V9;
# 00380
# 00381	    PyObject* py_V11;
# 00382
# 00383	        PyArrayObject* V11;
# 00384	        int type_num_V11;
# 00385	        typedef npy_float64 dtype_V11;
# 00386
# 00387	{
# 00388
# 00389	    py_V1 = PyList_GET_ITEM(storage_V1, 0);
# 00390	    {Py_XINCREF(py_V1);}
# 00391
# 00392	        if (py_V1 == Py_None)
# 00393	        {
# 00394
# 00395	        V1 = NULL;
# 00396	        type_num_V1 = NPY_FLOAT64;
# 00397
# 00398	        }
# 00399	        else
# 00400	        {
# 00401
# 00402	        V1 = NULL;
# 00403	        if (py_V1 == Py_None) {
# 00404	            // We can either fail here or set V1 to NULL and rely on Ops
# 00405	            // using tensors to handle the NULL case, but if they fail to do so
# 00406	            // they'll end up with nasty segfaults, so this is public service.
# 00407	            PyErr_SetString(PyExc_ValueError, "expected an ndarray, not None");
# 00408	            {
# 00409	        __failure = 2;
# 00410	        if (!PyErr_Occurred()) {
# 00411	            PyErr_SetString(PyExc_RuntimeError,
# 00412	                "Unexpected error in an Op's C code. "
# 00413	                "No Python exception was set.");
# 00414	            }
# 00415	        goto __label_2;}
# 00416	        }
# 00417	        if (!PyArray_Check(py_V1)) {
# 00418	            PyErr_SetString(PyExc_ValueError, "expected an ndarray");
# 00419	            {
# 00420	        __failure = 2;
# 00421	        if (!PyErr_Occurred()) {
# 00422	            PyErr_SetString(PyExc_RuntimeError,
# 00423	                "Unexpected error in an Op's C code. "
# 00424	                "No Python exception was set.");
# 00425	            }
# 00426	        goto __label_2;}
# 00427	        }
# 00428	        // We expect NPY_FLOAT64
# 00429	        type_num_V1 = PyArray_TYPE((PyArrayObject*) py_V1);
# 00430	        if (!PyArray_ISALIGNED((PyArrayObject*) py_V1)) {
# 00431	            PyArrayObject * tmp = (PyArrayObject*) py_V1;
# 00432	            PyErr_Format(PyExc_NotImplementedError,
# 00433	                         "expected an aligned array of type %ld "
# 00434	                         "(NPY_FLOAT64), got non-aligned array of type %ld"
# 00435	                         " with %ld dimensions, with 3 last dims "
# 00436	                         "%ld, %ld, %ld"
# 00437	                         " and 3 last strides %ld %ld, %ld.",
# 00438	                         (long int) NPY_FLOAT64,
# 00439	                         (long int) type_num_V1,
# 00440	                         (long int) PyArray_NDIM(tmp),
# 00441	                         (long int) PyArray_NDIM(tmp) >= 3 ?
# 00442	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00443	                         (long int) PyArray_NDIM(tmp) >= 2 ?
# 00444	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00445	                         (long int) PyArray_NDIM(tmp) >= 1 ?
# 00446	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-1] : -1,
# 00447	                         (long int) PyArray_NDIM(tmp) >= 3 ?
# 00448	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00449	                         (long int) PyArray_NDIM(tmp) >= 2 ?
# 00450	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00451	                         (long int) PyArray_NDIM(tmp) >= 1 ?
# 00452	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-1] : -1
# 00453	        );
# 00454	            {
# 00455	        __failure = 2;
# 00456	        if (!PyErr_Occurred()) {
# 00457	            PyErr_SetString(PyExc_RuntimeError,
# 00458	                "Unexpected error in an Op's C code. "
# 00459	                "No Python exception was set.");
# 00460	            }
# 00461	        goto __label_2;}
# 00462	        }
# 00463	        // This is a TypeError to be consistent with DEBUG_MODE
# 00464	        // Note: DEBUG_MODE also tells the name of the container
# 00465	        if (type_num_V1 != NPY_FLOAT64) {
# 00466	            PyErr_Format(PyExc_TypeError,
# 00467	                         "expected type_num %d (NPY_FLOAT64) got %d",
# 00468	                         NPY_FLOAT64, type_num_V1);
# 00469	            {
# 00470	        __failure = 2;
# 00471	        if (!PyErr_Occurred()) {
# 00472	            PyErr_SetString(PyExc_RuntimeError,
# 00473	                "Unexpected error in an Op's C code. "
# 00474	                "No Python exception was set.");
# 00475	            }
# 00476	        goto __label_2;}
# 00477	        }
# 00478	        V1 = (PyArrayObject*)(py_V1);
# 00479	        Py_XINCREF(V1);
# 00480
# 00481	        }
# 00482
# 00483	{
# 00484
# 00485	    py_V3 = PyList_GET_ITEM(storage_V3, 0);
# 00486	    {Py_XINCREF(py_V3);}
# 00487
# 00488	        V3 = NULL;
# 00489	        if (py_V3 == Py_None) {
# 00490	            // We can either fail here or set V3 to NULL and rely on Ops
# 00491	            // using tensors to handle the NULL case, but if they fail to do so
# 00492	            // they'll end up with nasty segfaults, so this is public service.
# 00493	            PyErr_SetString(PyExc_ValueError, "expected an ndarray, not None");
# 00494	            {
# 00495	        __failure = 4;
# 00496	        if (!PyErr_Occurred()) {
# 00497	            PyErr_SetString(PyExc_RuntimeError,
# 00498	                "Unexpected error in an Op's C code. "
# 00499	                "No Python exception was set.");
# 00500	            }
# 00501	        goto __label_4;}
# 00502	        }
# 00503	        if (!PyArray_Check(py_V3)) {
# 00504	            PyErr_SetString(PyExc_ValueError, "expected an ndarray");
# 00505	            {
# 00506	        __failure = 4;
# 00507	        if (!PyErr_Occurred()) {
# 00508	            PyErr_SetString(PyExc_RuntimeError,
# 00509	                "Unexpected error in an Op's C code. "
# 00510	                "No Python exception was set.");
# 00511	            }
# 00512	        goto __label_4;}
# 00513	        }
# 00514	        // We expect NPY_FLOAT64
# 00515	        type_num_V3 = PyArray_TYPE((PyArrayObject*) py_V3);
# 00516	        if (!PyArray_ISALIGNED((PyArrayObject*) py_V3)) {
# 00517	            PyArrayObject * tmp = (PyArrayObject*) py_V3;
# 00518	            PyErr_Format(PyExc_NotImplementedError,
# 00519	                         "expected an aligned array of type %ld "
# 00520	                         "(NPY_FLOAT64), got non-aligned array of type %ld"
# 00521	                         " with %ld dimensions, with 3 last dims "
# 00522	                         "%ld, %ld, %ld"
# 00523	                         " and 3 last strides %ld %ld, %ld.",
# 00524	                         (long int) NPY_FLOAT64,
# 00525	                         (long int) type_num_V3,
# 00526	                         (long int) PyArray_NDIM(tmp),
# 00527	                         (long int) PyArray_NDIM(tmp) >= 3 ?
# 00528	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00529	                         (long int) PyArray_NDIM(tmp) >= 2 ?
# 00530	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00531	                         (long int) PyArray_NDIM(tmp) >= 1 ?
# 00532	        PyArray_DIMS(tmp)[PyArray_NDIM(tmp)-1] : -1,
# 00533	                         (long int) PyArray_NDIM(tmp) >= 3 ?
# 00534	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-3] : -1,
# 00535	                         (long int) PyArray_NDIM(tmp) >= 2 ?
# 00536	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-2] : -1,
# 00537	                         (long int) PyArray_NDIM(tmp) >= 1 ?
# 00538	        PyArray_STRIDES(tmp)[PyArray_NDIM(tmp)-1] : -1
# 00539	        );
# 00540	            {
# 00541	        __failure = 4;
# 00542	        if (!PyErr_Occurred()) {
# 00543	            PyErr_SetString(PyExc_RuntimeError,
# 00544	                "Unexpected error in an Op's C code. "
# 00545	                "No Python exception was set.");
# 00546	            }
# 00547	        goto __label_4;}
# 00548	        }
# 00549	        // This is a TypeError to be consistent with DEBUG_MODE
# 00550	        // Note: DEBUG_MODE also tells the name of the container
# 00551	        if (type_num_V3 != NPY_FLOAT64) {
# 00552	            PyErr_Format(PyExc_TypeError,
# 00553	                         "expected type_num %d (NPY_FLOAT64) got %d",
# 00554	                         NPY_FLOAT64, type_num_V3);
# 00555	            {
# 00556	        __failure = 4;
# 00557	        if (!PyErr_Occurred()) {
# 00558	            PyErr_SetString(PyExc_RuntimeError,
# 00559	                "Unexpected error in an Op's C code. "
# 00560	                "No Python exception was set.");
# 00561	            }
# 00562	        goto __label_4;}
# 00563	        }
# 00564	        V3 = (PyArrayObject*)(py_V3);
# 00565	        Py_XINCREF(V3);
# 00566
# 00567	{
# 00568
# 00569	    py_V5 = PyList_GET_ITEM(storage_V5, 0);
# 00570	    {Py_XINCREF(py_V5);}
# 00571
# 00572	        V5 = NULL;
# 00573	        if (py_V5 == Py_None) {
# 00574	            // We can either fail here or set V5 to NULL and rely on Ops
# 00575	            // using tensors to handle the NULL case, but if they fail to do so
# 00576	            // they'll end up with nasty segfaults, so this is public service.
# 00577	            PyErr_SetString(PyExc_ValueError, "expected an ndarray, not None");
# 00578	            {
# 00579	        __failure = 6;
# 00580	        if (!PyErr_Occurred()) {
# 00581	            PyErr_SetString(PyExc_RuntimeError,
# 00582	                "Unexpected error in an Op's C code. "
# 00583	                "No Python exception was set.");
# 00584	            }
# 00585	        goto __label_6;}
# 00586	        }
# 00587	        if (!PyArray_Check(py_V5)) {
# 00588	            PyErr_SetString(PyExc_ValueError, "expected an ndarray");
# 00589	            {
# 00590	        __failure = 6;
# 00591	        if (!PyErr_Occurred()) {
# 00592	            PyErr_SetString(PyExc_RuntimeError,
# 00593	                "Unexpected error in an Op's C code. "
# 00594	                "No Python exception was set.");
# 00595	            }
# 00596	        goto __label_6;}
# 00597	        }
# 00598	        // We expect NPY_FLOAT64
# 00599	        type_num_V5 = PyArray_TYPE((PyArrayObject*) py_V5);
# 00600	        if (!PyArray_ISALIGNED((PyArrayObject*) py_V5)) {
# 00601	            PyArrayObject * tmp = (PyArrayObject*) py_V5;
# 00602	            PyErr_Format(PyExc_NotImplementedError,
# 00603	                         "expected an aligned array of type %ld "
# 00604	                         "(NPY_FLOAT64), got non-aligned array of type %ld"
# 00605	                         " with %ld dimensions, with 3 last dims "
# 00606	                         "%ld, %ld, %ld"
# 00607	                         " and 3 last strides %ld %ld, %ld.",
# 00608	                         (long int) NPY_FLOAT64,
# 00609	                         (long int) type_num_V5,
# 00610	                         (long int) PyArray_NDIM(tmp),
# ...
# 01249	                              (double*)yy_data, &Sy);
# 01250	                    }
# 01251	                    else
# 01252	                    {
# 01253	                        dgemv_(&TRANS, &Nx1, &Nx0,
# 01254	                            &alpha,
# 01255	                            (double*)(PyArray_DATA(V7)), &Sx0,
# 01256	                            (double*)yy_data, &Sy,
# 01257	                            &dbeta,
# 01258	                            (double*)zz_data, &Sz);
# 01259	                    }
# 01260	                }
# 01261	                else
# 01262	                {
# 01263	                    PyErr_SetString(PyExc_AssertionError,
# 01264	                                    "neither float nor double dtype");
# 01265	                    {
# 01266	        __failure = 13;
# 01267	        if (!PyErr_Occurred()) {
# 01268	            PyErr_SetString(PyExc_RuntimeError,
# 01269	                "Unexpected error in an Op's C code. "
# 01270	                "No Python exception was set.");
# 01271	            }
# 01272	        goto __label_13;}
# 01273	                }
# 01274	            }
# 01275	            else
# 01276	            {
# 01277	                PyErr_SetString(PyExc_AssertionError,
# 01278	                    "xx is a double-strided matrix, and should have been "
# 01279	                    "copied into a memory-contiguous one.");
# 01280	                {
# 01281	        __failure = 13;
# 01282	        if (!PyErr_Occurred()) {
# 01283	            PyErr_SetString(PyExc_RuntimeError,
# 01284	                "Unexpected error in an Op's C code. "
# 01285	                "No Python exception was set.");
# 01286	            }
# 01287	        goto __label_13;}
# 01288	            }
# 01289	        }
# 01290	        else if (dbeta != 1.0)
# 01291	        {
# 01292	            // the matrix has at least one dim of length 0
# 01293	            // so we do this loop, which either iterates over 0 elements
# 01294	            // or else it does the right thing for length-0 x.
# 01295	            dtype_V1 * zptr = (dtype_V1*)(PyArray_DATA(V1));
# 01296	            for (int i = 0; i < Nx0; ++i)
# 01297	            {
# 01298	                zptr[i * Sz] *= dbeta;
# 01299	            }
# 01300	        }
# 01301	    }
# 01302
# 01303	    __label_13:
# 01304
# 01305	double __DUMMY_13;
# 01306
# 01307	}
# 01308	__label_12:
# 01309
# 01310	        if (V11) {
# 01311	            Py_XDECREF(V11);
# 01312	        }
# 01313
# 01314	    {Py_XDECREF(py_V11);}
# 01315
# 01316	double __DUMMY_12;
# 01317
# 01318	}
# 01319	__label_10:
# 01320
# 01321	        if (V9) {
# 01322	            Py_XDECREF(V9);
# 01323	        }
# 01324
# 01325	    {Py_XDECREF(py_V9);}
# 01326
# 01327	double __DUMMY_10;
# 01328
# 01329	}
# 01330	__label_8:
# 01331
# 01332	        if (V7) {
# 01333	            Py_XDECREF(V7);
# 01334	        }
# 01335
# 01336	    {Py_XDECREF(py_V7);}
# 01337
# 01338	double __DUMMY_8;
# 01339
# 01340	}
# 01341	__label_6:
# 01342
# 01343	        if (V5) {
# 01344	            Py_XDECREF(V5);
# 01345	        }
# 01346
# 01347	    {Py_XDECREF(py_V5);}
# 01348
# 01349	double __DUMMY_6;
# 01350
# 01351	}
# 01352	__label_4:
# 01353
# 01354	        if (V3) {
# 01355	            Py_XDECREF(V3);
# 01356	        }
# 01357
# 01358	    {Py_XDECREF(py_V3);}
# 01359
# 01360	double __DUMMY_4;
# 01361
# 01362	}
# 01363	__label_2:
# 01364
# 01365	    if (!__failure) {
# 01366
# 01367	        {Py_XDECREF(py_V1);}
# 01368	        if (!V1) {
# 01369	            Py_INCREF(Py_None);
# 01370	            py_V1 = Py_None;
# 01371	        }
# 01372	        else if ((void*)py_V1 != (void*)V1) {
# 01373	            py_V1 = (PyObject*)V1;
# 01374	        }
# 01375
# 01376	        {Py_XINCREF(py_V1);}
# 01377
# 01378	        if (V1 && !PyArray_ISALIGNED((PyArrayObject*) py_V1)) {
# 01379	            PyErr_Format(PyExc_NotImplementedError,
# 01380	                         "c_sync: expected an aligned array of type %ld "
# 01381	                         "(NPY_FLOAT64), got non-aligned array of type %ld"
# 01382	                         " with %ld dimensions, with 3 last dims "
# 01383	                         "%ld, %ld, %ld"
# 01384	                         " and 3 last strides %ld %ld, %ld.",
# 01385	                         (long int) NPY_FLOAT64,
# 01386	                         (long int) type_num_V1,
# 01387	                         (long int) PyArray_NDIM(V1),
# 01388	                         (long int) PyArray_NDIM(V1) >= 3 ?
# 01389	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-3] : -1,
# 01390	                         (long int) PyArray_NDIM(V1) >= 2 ?
# 01391	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-2] : -1,
# 01392	                         (long int) PyArray_NDIM(V1) >= 1 ?
# 01393	        PyArray_DIMS(V1)[PyArray_NDIM(V1)-1] : -1,
# 01394	                         (long int) PyArray_NDIM(V1) >= 3 ?
# 01395	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-3] : -1,
# 01396	                         (long int) PyArray_NDIM(V1) >= 2 ?
# 01397	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-2] : -1,
# 01398	                         (long int) PyArray_NDIM(V1) >= 1 ?
# 01399	        PyArray_STRIDES(V1)[PyArray_NDIM(V1)-1] : -1
# 01400	        );
# 01401	            {
# 01402	        __failure = 2;
# 01403	        if (!PyErr_Occurred()) {
# 01404	            PyErr_SetString(PyExc_RuntimeError,
# 01405	                "Unexpected error in an Op's C code. "
# 01406	                "No Python exception was set.");
# 01407	            }
# 01408	        goto __label_2;}
# 01409	        }
# 01410
# 01411	      PyObject* old = PyList_GET_ITEM(storage_V1, 0);
# 01412	      {Py_XINCREF(py_V1);}
# 01413	      PyList_SET_ITEM(storage_V1, 0, py_V1);
# 01414	      {Py_XDECREF(old);}
# 01415	    }
# 01416
# 01417	        if (V1) {
# 01418	            Py_XDECREF(V1);
# 01419	        }
# 01420
# 01421	    {Py_XDECREF(py_V1);}
# 01422
# 01423	double __DUMMY_2;
# 01424
# 01425	}
# 01426
# 01427
# 01428	        if (__failure) {
# 01429	            // When there is a failure, this code puts the exception
# 01430	            // in __ERROR.
# 01431	            PyObject* err_type = NULL;
# 01432	            PyObject* err_msg = NULL;
# 01433	            PyObject* err_traceback = NULL;
# 01434	            PyErr_Fetch(&err_type, &err_msg, &err_traceback);
# 01435	            if (!err_type) {err_type = Py_None;Py_INCREF(Py_None);}
# 01436	            if (!err_msg) {err_msg = Py_None; Py_INCREF(Py_None);}
# 01437	            if (!err_traceback) {err_traceback = Py_None; Py_INCREF(Py_None);}
# 01438	            PyObject* old_err_type = PyList_GET_ITEM(__ERROR, 0);
# 01439	            PyObject* old_err_msg = PyList_GET_ITEM(__ERROR, 1);
# 01440	            PyObject* old_err_traceback = PyList_GET_ITEM(__ERROR, 2);
# 01441	            PyList_SET_ITEM(__ERROR, 0, err_type);
# 01442	            PyList_SET_ITEM(__ERROR, 1, err_msg);
# 01443	            PyList_SET_ITEM(__ERROR, 2, err_traceback);
# 01444	            {Py_XDECREF(old_err_type);}
# 01445	            {Py_XDECREF(old_err_msg);}
# 01446	            {Py_XDECREF(old_err_traceback);}
# 01447	        }
# 01448	        // The failure code is returned to index what code block failed.
# 01449	        return __failure;
# 01450
# 01451	        }
# 01452	    };
# 01453
# 01454
# 01455	        int __struct_compiled_op_f669e97685c3ebc76359b78f6a28a991_executor(__struct_compiled_op_f669e97685c3ebc76359b78f6a28a991* self) {
# 01456	            return self->run();
# 01457	        }
# 01458
# 01459	        void __struct_compiled_op_f669e97685c3ebc76359b78f6a28a991_destructor(void* executor, void* self) {
# 01460	            delete ((__struct_compiled_op_f669e97685c3ebc76359b78f6a28a991*)self);
# 01461	        }
# 01462
# 01463	//////////////////////
# 01464	////  Functions
# 01465	//////////////////////
# 01466	static PyObject * instantiate(PyObject * self, PyObject *argtuple) {
# 01467	  assert(PyTuple_Check(argtuple));
# 01468	  if (7 != PyTuple_Size(argtuple)){
# 01469	     PyErr_Format(PyExc_TypeError, "Wrong number of arguments, expected 7, got %i", (int)PyTuple_Size(argtuple));
# 01470	     return NULL;
# 01471	  }
# 01472	  __struct_compiled_op_f669e97685c3ebc76359b78f6a28a991* struct_ptr = new __struct_compiled_op_f669e97685c3ebc76359b78f6a28a991();
# 01473	  struct_ptr->init( PyTuple_GET_ITEM(argtuple, 0),PyTuple_GET_ITEM(argtuple, 1),PyTuple_GET_ITEM(argtuple, 2),PyTuple_GET_ITEM(argtuple, 3),PyTuple_GET_ITEM(argtuple, 4),PyTuple_GET_ITEM(argtuple, 5),PyTuple_GET_ITEM(argtuple, 6) );
# 01474	  PyObject* thunk = PyCObject_FromVoidPtrAndDesc((void*)(&__struct_compiled_op_f669e97685c3ebc76359b78f6a28a991_executor), struct_ptr, __struct_compiled_op_f669e97685c3ebc76359b78f6a28a991_destructor);
# 01475	  return thunk; }
# 01476
# 01477	//////////////////////
# 01478	////  Module init
# 01479	//////////////////////
# 01480	static PyMethodDef MyMethods[] = {
# 01481		{"instantiate", instantiate, METH_VARARGS, "undocumented"} ,
# 01482		{NULL, NULL, 0, NULL}
# 01483	};
# 01484	PyMODINIT_FUNC initf669e97685c3ebc76359b78f6a28a991(void){
# 01485	   import_array();
# 01486	   (void) Py_InitModule("f669e97685c3ebc76359b78f6a28a991", MyMethods);
# 01487	}
# 01488
# Problem occurred during compilation with the command line below:
# g++ -shared -g -O3 -fno-math-errno -Wno-unused-label -Wno-unused-variable -Wno-write-strings -Wl,-rpath,/home/gab/anaconda/lib -D NPY_NO_DEPRECATED_API=NPY_1_7_API_VERSION -m64 -fPIC -I/home/gab/anaconda/lib/python2.7/site-packages/numpy/core/include -I/home/gab/anaconda/include/python2.7 -o /home/gab/.theano/compiledir_Linux-3.13.0-37-generic-x86_64-with-debian-jessie-sid-x86_64-2.7.8-64/tmpexnp1o/f669e97685c3ebc76359b78f6a28a991.so /home/gab/.theano/compiledir_Linux-3.13.0-37-generic-x86_64-with-debian-jessie-sid-x86_64-2.7.8-64/tmpexnp1o/mod.cpp -L/home/gab/anaconda/lib -lpython2.7 -lf77blas -lcblas -latlas
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-65-406f98797db2> in <module>()
#      37           inputs=[x,y],
#      38           outputs=[prediction, xent],
# ---> 39           updates=((w, w - 0.1 * gw), (b, b - 0.1 * gb)))
#      40 predict = theano.function(inputs=[x], outputs=prediction)
#      41
#
# /home/gab/anaconda/lib/python2.7/site-packages/theano/compile/function.pyc in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     221                 allow_input_downcast=allow_input_downcast,
#     222                 on_unused_input=on_unused_input,
# --> 223                 profile=profile)
#     224     # We need to add the flag check_aliased inputs if we have any mutable or
#     225     # borrowed used defined inputs
#
# /home/gab/anaconda/lib/python2.7/site-packages/theano/compile/pfunc.pyc in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     510     return orig_function(inputs, cloned_outputs, mode,
#     511             accept_inplace=accept_inplace, name=name, profile=profile,
# --> 512             on_unused_input=on_unused_input)
#     513
#     514
#
# /home/gab/anaconda/lib/python2.7/site-packages/theano/compile/function_module.pyc in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input)
#    1310                    profile=profile,
#    1311                    on_unused_input=on_unused_input).create(
# -> 1312                        defaults)
#    1313
#    1314     t2 = time.time()
#
# /home/gab/anaconda/lib/python2.7/site-packages/theano/compile/function_module.pyc in create(self, input_storage, trustme)
#    1179         # Get a function instance
#    1180         start_linker = time.time()
# -> 1181         _fn, _i, _o = self.linker.make_thunk(input_storage=input_storage_lists)
#    1182         end_linker = time.time()
#    1183
#
# /home/gab/anaconda/lib/python2.7/site-packages/theano/gof/link.pyc in make_thunk(self, profiler, input_storage, output_storage)
#     432         return self.make_all(profiler=profiler,
#     433                              input_storage=input_storage,
# --> 434                              output_storage=output_storage)[:3]
#     435
#     436     def make_all(self, profiler, input_storage, output_storage):
#
# /home/gab/anaconda/lib/python2.7/site-packages/theano/gof/vm.pyc in make_all(self, profiler, input_storage, output_storage)
#     845                                                  storage_map,
#     846                                                  compute_map,
# --> 847                                                  no_recycling))
#     848             except Exception, e:
#     849                 e.args = ("The following error happened while"
#
# /home/gab/anaconda/lib/python2.7/site-packages/theano/gof/op.pyc in make_thunk(self, node, storage_map, compute_map, no_recycling)
#     604                 logger.debug('Trying CLinker.make_thunk')
#     605                 outputs = cl.make_thunk(input_storage=node_input_storage,
# --> 606                                         output_storage=node_output_storage)
#     607                 fill_storage, node_input_filters, node_output_filters = outputs
#     608
#
# /home/gab/anaconda/lib/python2.7/site-packages/theano/gof/cc.pyc in make_thunk(self, input_storage, output_storage, keep_lock)
#     946         cthunk, in_storage, out_storage, error_storage = self.__compile__(
#     947             input_storage, output_storage,
# --> 948             keep_lock=keep_lock)
#     949
#     950         res = _CThunk(cthunk, init_tasks, tasks, error_storage)
#
# /home/gab/anaconda/lib/python2.7/site-packages/theano/gof/cc.pyc in __compile__(self, input_storage, output_storage, keep_lock)
#     889                                     input_storage,
#     890                                     output_storage,
# --> 891                                     keep_lock=keep_lock)
#     892         return (thunk,
#     893                 [link.Container(input, storage) for input, storage in
#
# /home/gab/anaconda/lib/python2.7/site-packages/theano/gof/cc.pyc in cthunk_factory(self, error_storage, in_storage, out_storage, keep_lock)
#    1320         else:
#    1321             module = get_module_cache().module_from_key(
# -> 1322                 key=key, fn=self.compile_cmodule_by_step, keep_lock=keep_lock)
#    1323
#    1324         vars = self.inputs + self.outputs + self.orphans
#
# /home/gab/anaconda/lib/python2.7/site-packages/theano/gof/cmodule.pyc in module_from_key(self, key, fn, keep_lock, key_data)
#     994                                 # The module should be returned by the last
#     995                                 # step of the compilation.
# --> 996                                 module = next(compile_steps)
#     997                             except StopIteration:
#     998                                 break
#
# /home/gab/anaconda/lib/python2.7/site-packages/theano/gof/cc.pyc in compile_cmodule_by_step(self, location)
#    1235                     lib_dirs=self.lib_dirs(),
#    1236                     libs=libs,
# -> 1237                     preargs=preargs)
#    1238             except Exception, e:
#    1239                 e.args += (str(self.fgraph),)
#
# /home/gab/anaconda/lib/python2.7/site-packages/theano/gof/cmodule.pyc in compile_str(module_name, src_code, location, include_dirs, lib_dirs, libs, preargs, py_module)
#    1969             # difficult to read.
#    1970             raise Exception('Compilation failed (return status=%s): %s' %
# -> 1971                             (status, compile_stderr.replace('\n', '. ')))
#    1972         elif config.cmodule.compilation_warning and compile_stderr:
#    1973             # Print errors just below the command line.
#
# Exception: ('The following error happened while compiling the node', CGemv{inplace}(Alloc.0, TensorConstant{1.0}, x, w, TensorConstant{0.0}), '\n', 'Compilation failed (return status=1): /usr/bin/ld: cannot find -lf77blas. /usr/bin/ld: cannot find -lcblas. /usr/bin/ld: cannot find -latlas. collect2: error: ld returned 1 exit status. ', '[CGemv{inplace}(<TensorType(float64, vector)>, TensorConstant{1.0}, x, w, TensorConstant{0.0})]')
