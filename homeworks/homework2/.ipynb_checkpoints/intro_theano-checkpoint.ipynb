# %%
import theano.tensor as T
from theano import function

# define variables to add
# dscalar is a theano type:
# - scalar = 0-dmensional array
# - double precision
x = T.dscalar('x')
y = T.dscalar('y')

# 
z = x + y

# f will be compiled to C code
f = function([x,y], z)

# %%
f(2,3)
# Out:
# array(5.0)

# %%
type(x)
# Out:
# theano.tensor.var.TensorVariable

# %% [markdown]
# ## Matrix additions

# %%
x = T.dmatrix('x')
y = T.dmatrix('y')
z = x + y
f = function([x, y], z)

# %%
f([[1,2],[3,4]], [[5,6],[7,8]])
# Out:
# array([[  6.,   8.],
#        [ 10.,  12.]])

# %%
a = T.vector()
b = T.vector()
out = (a ** 2) + (b ** 2) + (2 * a * b)
f = function([a, b], out)
f([1,2], [4,5])
# Out:
# array([ 25.,  49.])

# %% [markdown]
# ## Logistic function

# %%
x = T.dmatrix('x')
# this is the equation of the logistic equation
s = 1 / (1 + T.exp(-x))
logistic = function([x], s)
logistic([[0, 1], [-1, -2]])
# Out:
# array([[ 0.5       ,  0.73105858],
#        [ 0.26894142,  0.11920292]])

# %%
# apparently, logistic equation is equivalent to this one
s2 = (1 + T.tanh(x / 2)) / 2
logistic2 = function([x], s2)
logistic2([[0, 1], [-1, -2]])
# Out:
# array([[ 0.5       ,  0.73105858],
#        [ 0.26894142,  0.11920292]])

# %%
# let's try matrix abs diff and squared diff

x, y = T.dmatrices('x', 'y')

abs_diff = abs(x - y)
squared_diff = (x - y) * (x - y)
f = function([x,y], [abs_diff, squared_diff])

f([[1,2],[3,4]], [[4,3],[2,1]])
# Out:
# [array([[ 3.,  1.],
#         [ 1.,  3.]]), array([[ 9.,  1.],
#         [ 1.,  9.]])]

# %% [markdown]
# ## Default values and named arguments

# %%
# set default values in the function declaration
from theano import Param
x, y = T.dscalars('x', 'y')
z = x + (y/2-12)
f = function([Param(x, name='x'), Param(y, default=42, name='y')], z)
print f(33)
print f(33, 42)
print(f(y=42, x=33))
# Out:
# 42.0
# 42.0
# 42.0

# %% [markdown]
# ## Shared variables

# %%
# used to make an accumulator for example, could be thought as a class variable in Java I think
from theano import shared
state = shared(0)
inc = T.iscalar('inc') # integer scalar
accumulator = function([inc], state, updates=[(state, state+inc)])

accumulator(0)
accumulator(200)
state.get_value()
# Out:
# array(200)

# %% [markdown]
# ## Random numbers

# %%
# random stream interface as in ssj
from theano.tensor.shared_randomstreams import RandomStreams
from theano import function
srng = RandomStreams()

rv_u = srng.uniform((2,2))
rv_n = srng.normal((2,2))
f = function([], rv_u)
g = function([], rv_n, no_default_updates=True) # no update to rv_n.rng
nearly_zeros = function([], rv_u + rv_u - 2 * rv_u)

# %% [markdown]
# ## Logistic regression

# %%
import numpy
import theano
import theano.tensor as T
rng = numpy.random

N = 400
feats = 784
D = (rng.randn(N, feats), rng.randint(size=N, low=0, high=2))
training_steps = 10000

# declare theano symbolic variables
# observations (x,y), it's supervised learning...
x = T.matrix('x')
y = T.vector('y')
# weights and biases
w = theano.shared(rng.randn(feats), name='w')
b = theano.shared(0., name="b")

#print "Initial model:"
#print w.get_value(), b.get_value()

# construct theano expression graph (will have to dig deeper on the meaning of expresison graph)
# could be simply an AST?
# actually, it's the way mathematical expressions are symbolically represented internally...

# Construct Theano expression graph
p_1 = 1 / (1 + T.exp(-T.dot(x, w) - b))   # Probability that target = 1
prediction = p_1 > 0.5                    # The prediction thresholded
xent = -y * T.log(p_1) - (1-y) * T.log(1-p_1) # Cross-entropy loss function
cost = xent.mean() + 0.01 * (w ** 2).sum()# The cost to minimize
gw, gb = T.grad(cost, [w, b])             # Compute the gradient of the cost
                                          # (we shall return to this in a
                                          # following section of this tutorial)

# Compile
train = theano.function(
          inputs=[x,y],
          outputs=[prediction, xent],
          updates=((w, w - 0.1 * gw), (b, b - 0.1 * gb)))
predict = theano.function(inputs=[x], outputs=prediction)

# Train
for i in range(training_steps):
    pred, err = train(D[0], D[1])

#print "Final model:"
#print w.get_value(), b.get_value()
#print "target values for D:", D[1]
#print "prediction on D:", predict(D[0])

print sum(D[1] == predict(D[0]))
print sum(D[1] == predict(D[0])) / len(D)
# Out:
# Initial model:
# [  6.85831609e-04  -1.66213243e+00  -6.80427675e-01  -1.69647330e+00
#    1.93858121e+00  -1.61914440e+00  -6.30490665e-01   5.56562913e-01
#   -1.31071510e+00   6.34771852e-01  -1.16974466e+00   3.25008983e-01
#   -3.99565599e-01  -2.03342613e+00   1.05632115e+00  -4.34688610e-01
#   -2.80149119e-01  -4.44783072e-01   1.24862536e+00  -2.06564599e-01
#   -8.10938516e-01   6.65085745e-01   4.67212602e-01   8.54228930e-01
#    1.52108878e+00   1.42614325e+00  -1.52920872e+00   5.49569548e-02
#   -3.58800807e-01  -2.98291800e-01  -1.31144137e+00  -9.47688031e-01
#   -1.05312077e+00  -1.99506563e-01  -5.82291891e-01   1.23624878e+00
#   -3.41467018e-01  -4.96392136e-01   1.46384407e+00  -1.64944630e+00
#   -2.68722738e-01  -1.94921750e+00   1.06633596e+00   1.43582795e-01
#    1.40837561e+00  -1.73586850e+00  -3.21971099e-01  -9.37108795e-01
#    3.97201576e-01  -1.51339133e+00  -1.48415517e+00   9.57997677e-01
#   -1.67236804e+00  -1.31103793e+00  -5.36171154e-02  -8.86126532e-01
#    1.21556909e+00   7.96431954e-02  -5.34977141e-01   3.44521820e-01
#    4.47766784e-01  -1.25423273e+00   4.57507413e-01  -6.12968006e-01
#    7.93186556e-01  -4.25326779e-01   1.17911557e+00   1.29503863e+00
#   -1.18816199e+00   1.62928925e-02  -1.16449864e+00   1.72701832e+00
#   -1.72239485e-01  -9.32012517e-01  -1.83978323e+00  -2.32462502e-01
#    1.04529433e+00  -2.63086643e-01   8.45636045e-01   1.85126934e+00
#   -1.40262209e+00   9.22590163e-01  -5.13812423e-01   1.49362636e+00
#    9.94742078e-02  -3.91385105e-01   2.06438430e-01   1.86611537e-01
#   -6.30458490e-01  -1.32393737e+00  -1.56319508e+00   1.00057077e+00
#    2.34033466e-01  -8.37052195e-01  -4.10346038e-01   7.88499990e-01
#   -2.92843015e-02   6.54479032e-01   9.84676206e-01   2.53465817e-01
#   -6.90931045e-01  -1.41764854e+00  -1.69172458e+00   1.12022621e+00
#   -8.00222815e-01   8.80066703e-01  -4.60991214e-02  -9.99724975e-01
#    4.82432741e-01   1.07885290e+00   5.12587307e-01   9.09545841e-03
#   -5.71591595e-01  -4.98882934e-01   1.39529316e+00  -8.47369956e-02
#    2.09951322e+00  -1.95956196e-01  -1.52554179e+00   3.87531153e-02
#    4.83304398e-01  -8.77215778e-01  -1.41599818e+00  -2.36997804e+00
