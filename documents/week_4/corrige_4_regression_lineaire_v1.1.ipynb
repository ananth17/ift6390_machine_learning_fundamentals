# %% [markdown]
# # Régression linéaire

# %% [markdown]
# Le prochain modèle abordé sera la régression linéaire avant de voir la classification linéaire à la prochaine séance. La régression se définit par la simple formule suivante
#
# $$\hat{y} =\sum_{j=1}^d w_jx_j+b$$
#
# Où $d$ est le nombre de dimension de l'exemple $x$. $w$ et $b$ sont les poids et le biais respectivement. $\hat{y}$ cera aujourd'hui un simple scalaire, mais il pourrait aussi être un vecteur et dans ce cas $W$ devrait être une matrice!
#
# Pour entraîner le modèle, on va minimiser l'erreur quadratique
#
# $$E = \frac{1}{n}\sum_{i=1}^n (y_i-\hat{y_i})^2$$
#
# L'algorithme de descente de gradient est frequemment utilisé comme règle de mise à jour des paramètres afin d'optimiser l'erreur. Pour l'utiliser, nous devons calculer le gradient de l'erreur par rapport à nos paramètres, soit $w$ et $b$. Nous aurons ensuite la règle de mise à jour pour atteindre l'erreur minimale.
#
# Calculez le gradient par rapport à $w$ et $b$ et passez à la première section. N'hésitez pas à poser des question!

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# %aimport numpy
np=numpy
import utilitaires4
import time
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 1 - Régression linéaire en ligne

# %% [markdown]
# La descente de gradient stochastique (c'est-à-dire où on fait une mise à jour par exemple visité) est facile à implémenter. Nous commencerons donc par celle-ci. Vous implémenterez la descente de gradient par batch à la prochaine section.
#
# La première fonction à apprendre par votre modèle est celle affiché par le code suivant.

# %%
x, y = utilitaires4.fonction_1()

plt.scatter(x, y)

plt.show()

# %% [markdown]
# Completez la fonction `apprend_enligne` et exécutez la cellule suivante pour tester son apprentissage. Le modèle devrait ajuster ses paramètres aux données sans problèmes. Regardez l'erreur qui devrait diminuer à chaque époque et la représentation du modèle qui devrait s'approcher des données sur le graphique.
#
# La mise à jour stochastique se fait de la manière suivante
#
# $$ w_{t+1} \leftarrow w_t - \eta\frac{\partial E_i}{\partial W}$$
#
# $$ b_{t+1} \leftarrow b_t - \eta\frac{\partial E_i}{\partial b}$$
#
# Où $\eta$ est le taux d'apprentissage, un hyper-paramètre qu'il faut ajuster à la main pour optimiser l'apprentissage de l'algorithme. $E_i$ est l'erreur quadratique sur l'exemple $x_i$. Il n'y a donc pas de somme $\sum_{i=0}^n$. Regardez l'équation de la section 2 pour comparer si ça ne vous semble pas clair.

# %%
def apprend_enligne(x, y, n_epoch, learning_rate):
    """
    Apprend les paramètres w et b en minimisant l'erreur de quadratique de manière stochastique.
        
    Parameters
    ----------
    x : array
        vecteur d'exemples, chaque exemple est de dimension 1. x est donc un vecteur de dimension n
    y : array
        vecteur de cibles de dimensions n
    n_epoch : int
        nombre d'époque d'entraînement
    learning_rate : float
        taux d'apprentissage de l'algorithme

    Returns
    -------
    w : float
        poids dans la formule y = w*x + b
    b : float
        biais dans la formule y = w*x + b
    """
    
    # on initialise les paramètres W et b
    w = 0.
    b = 1

    start = time.clock()
    # pour chaque époque
    for i in range(n_epoch):
        
        # pour chaque example de l'ensemble
        for j in xrange(x.shape[0]):
            y_hat = (x[j]*w + b) # calculez y
            w_grad = x[j] * (y[j] - y_hat)
            b_grad = (y[j] - y_hat)
            w = w + learning_rate * w_grad
            b = b + learning_rate * b_grad

        if i%(n_epoch/4) == 0:
            y_hat = x*w + b
            utilitaires4.plot(x, y, y_hat)
            
            print "époque #%d" % (i+1)
            print "erreur quadratique = %f" % (np.sum((y-y_hat)**2)/float(x.shape[0]))
    end = time.clock()

    print "L'entraînement a pris %f seconds (%d exemples visité par seconde)" % (end-start, (n_epoch*x.shape[0])/float(end-start))
    
    return w, b

# %%
x, y = utilitaires4.fonction_1()

w, b = apprend_enligne(x, y, n_epoch=20, learning_rate=0.1)

plt.clf()

print "w=%f, b=%f" % (w, b)
# Out:
# époque #1
# erreur quadratique = 0.126090
# époque #6
# erreur quadratique = 0.006716
# époque #11
# erreur quadratique = 0.001969
# époque #16
# erreur quadratique = 0.001775
# L'entraînement a pris 0.742837 seconds (6730 exemples visité par seconde)
# w=0.859222, b=0.076966

# %% [markdown]
# ## 2 - Régression linéaire par batch

# %% [markdown]
# Completez la fonction `apprend_par_batch` et exécutez la cellule suivante pour tester son apprentissage.
#
# La mise à jour par batch se fait de la manière suivante
#
# $$ w_{t+1} \leftarrow w_t - \eta\frac{1}{n}\sum_{i=1}^n\frac{\partial E_i}{\partial W}$$
#
# $$ b_{t+1} \leftarrow b_t - \eta\frac{1}{n}\sum_{i=1}^n\frac{\partial E_i}{\partial b}$$
#
# Où $\eta$, encore une fois, est le taux d'apprentissage. Remarquez qu'ici on somme bien sur tout l'ensemble. Il y aura donc une seule mise à jour par époque, mais elle sera beaucoup moins bruitée.

# %%
def apprend_par_batch(x, y, n_epoch, learning_rate):
    """
    Apprend les paramètres w et b en minimisant l'erreur de quadratique par batch.
        
    Parameters
    ----------
    x : array
        vecteur d'exemples, chaque exemple est de dimension 1. x est donc un vecteur de dimension n
    y : array
        vecteur de cibles de dimensions n
    n_epoch : int
        nombre d'époque d'entraînement
    learning_rate : float
        taux d'apprentissage de l'algorithme

    Returns
    -------
    w : float
        poids dans la formule y = w*x + b
    b : float
        biais dans la formule y = w*x + b
    """
    
    # on initialise les paramètres W et b
    w = 0.
    b = 1

    start = time.clock()
    # pour chaque époque
    for i in range(n_epoch):

        y_hat = x*w + b # calculez y_hat sur tout l'ensemble
        w_grad = np.mean(x * (y-y_hat))
        b_grad = np.mean(y-y_hat)
        w = w + learning_rate * w_grad
        b = b + learning_rate * b_grad

        if i%(n_epoch/4) == 0:
            y_hat = x*w + b
            utilitaires4.plot(x, y, y_hat)
            
            print "époque #%d" % (i+1)
            print "erreur quadratique = %f" % (np.sum((y-y_hat)**2)/float(x.shape[0]))

    end = time.clock()

    print "L'entraînement a pris %f seconds (%d exemples visité par seconde)" % (end-start, (n_epoch*x.shape[0])/float(end-start))
        
    return w, b

# %%
x, y = utilitaires4.fonction_1()
print len(x)
w, b = apprend_par_batch(x, y, n_epoch=250, learning_rate=0.2)
    
plt.clf()

print "w=%f, b=%f" % (w, b)
# Out:
# 250
# époque #1
# erreur quadratique = 0.229264
# époque #63
# erreur quadratique = 0.021697
# époque #125
# erreur quadratique = 0.005667
# époque #187
# erreur quadratique = 0.002601
# époque #249
# erreur quadratique = 0.002015
# L'entraînement a pris 0.987062 seconds (63319 exemples visité par seconde)
# w=0.880013, b=0.054000

# %% [markdown]
# Avez vous remarqué la différence de temps de calcul? Le temps absolu de convergence est le même (en seconde), mais plus d'exemples ont été vu dans le même temps pour l'entraînement par batch. Il existe un compromis pour les ensembles trop gros où calculer la moyenne totale à chaque époque prendrait trop de temps. On appelle ce compromis les mini-batch. On itère à travers l'ensemble comme avec la descente de gradient stochastique, mais par mini-batch où on calcule la moyenne. Nous verrons cela plus en détail dans une prochaine démo.

# %% [markdown]
# ## 3 - Régression linéaire sur données non linéaires

# %% [markdown]
# Enfin, c'est bien beau tout ça, mais des données linéaires, ça ne court pas les rues. Il existe malgré tout une astuce pour permettre d'entraîner efficacement un modèle linéaire sur des données non-linéaires. Il suffit de transformer les données en ajoutant des dimensions. Nous verrons l'astuce du noyaux qui en découle d'ici quelques séances. Pour l'instant, nous verrons qu'on peut apprendre un polynôme avec un modèle linéaire.
#
# Exécutez la cellule suivante et observez le comportement du modèle linéaire sur un simple polynome de troisième degrée.

# %%
x, y = utilitaires4.fonction_2()
w, b = apprend_par_batch(x, y, n_epoch=250, learning_rate=0.1)
    
plt.clf()

print "w=%f, b=%f" % (w, b)
# Out:
# époque #1
# erreur quadratique = 0.189014
# époque #63
# erreur quadratique = 0.024744
# époque #125
# erreur quadratique = 0.014413
# époque #187
# erreur quadratique = 0.009882
# époque #249
# erreur quadratique = 0.007895
# L'entraînement a pris 0.903674 seconds (69162 exemples visité par seconde)
# w=0.392103, b=0.357258

# %% [markdown]
# Pas terrible hein? Il suffit maintenant d'augmenter l'ensemble de donnée en y ajoutant les valeurs de $x$ au carrée, au cube, etc. Completez la fonction suivante. Vous aurez besoin de la fonction `numpy.concatenate`. Pensez bien à quel axe utiliser! Exécutez la cellule prochaine pour tester votre implémentation.

# %%
def polynomes(x,p=2):
    """
    Prend les examples x et concatene les degrées suivant
    
    Prend en entrée une matrice X pouvant avoir plus d'une dimension.
        
    Parameters
    ----------
    x : array
        vecteur de dimension n
    p : int
        degrée maximal. la matrice retourné aura les degrées 1 à p inclusivement

    Returns
    -------
    X : array
        matrice de dimension (n, p)
        
    Examples
    --------
    >>> x = np.array([1,2,3])
    >>> polynomes(x, n=3)
    [[1, 1,  1],
     [2, 4,  8],
     [3, 9, 27]]
    """
    
    # premièrement reshaper x pour pouvoir le concatener sur le bon axe
    X = x.reshape((x.shape[0], 1))
    # maintenant faire la concatenation avec les degrées demandés
    X = np.concatenate([X**i for i in xrange(1,p+1)],axis=1)
    
    return X

# %%
x, y = utilitaires4.fonction_2()

# test avec polynome = 2
assert polynomes(x,p=2).shape == (x.shape[0], 2), \
    "Le polynome de degré deux devrait avoir le format %s, mais a le format %s" % \
        ((x.shape[0], 2), polynomes(x, p=2).shape)
assert np.allclose(polynomes(x,p=2)[:,1], x**2), "La deuxième dimension devrait être X**2" 

# test avec polynome = 5
assert polynomes(x,p=5).shape == (x.shape[0], 5), \
    "Le polynome de degré cinq devrait avoir le format %s, mais a le format %s" % \
        ((x.shape[0], 2), polynomes(x, p=2).shape)
assert np.allclose(polynomes(x,p=5)[:,4], x**5), "La cinquième dimension devrait être X**5" 

print "La fonction polynomes passe les tests!"
# Out:
# La fonction polynomes passe les tests!

# %% [markdown]
# Il reste enfin à implémenter la function `apprend_par_batch_multi_dim`. Elle est essentiellement la même fonction que `apprend_par_batch` à la différence près que maintenant le `X` en entrée est une matrice et nous avons un **vecteur** de poids `w` et non plus un simple **scalaire**. Vous pourrez finalement tester la dernière implémentation de la démo en exécutant la denière cellule. N'oubliez pas de jouer avec la valeur de p dans la fonction `polynomes` pour observer l'impact sur le comportememt du modèle linéaire.

# %%
x = None
def apprend_par_batch_multi_dim(X, y, n_epoch, learning_rate):
    """
    Apprend les paramètres w et b en minimisant l'erreur de quadratique par batch.
    
    Prend en entrée une matrice X pouvant avoir plus d'une dimension.
        
    Parameters
    ----------
    x : array
        matrice d'exemples de dimensions (n,d). Où n est le nombre d'exemples 
        et d le nombre de dimensions de chaque exemple
    y : array
        vecteur de cibles de dimensions n
    n_epoch : int
        nombre d'époque d'entraînement
    learning_rate : float
        taux d'apprentissage de l'algorithme

    Returns
    -------
    w : array
        vecteur de poids de dimension d dans la formule y = w*x + b où w et x sont des vecteurs
    b : float
        biais dans la formule y = w*x + b où w et x sont des vecteurs
    """
    
    # on initialise les paramètres W et b
    w = np.zeros(X.shape[1])
    b = 1

    start = time.clock()
    # pour chaque époque
    for i in range(n_epoch):
        y_hat = (np.dot(X,w)+b)
        w_grad = 2 * X * (y-y_hat)[:,None]
        b_grad = 2 * (y-y_hat)[:,None]
        w = w + learning_rate * np.mean(w_grad,axis=0)
        b = b + learning_rate * np.mean(b_grad,axis=0)

        if i%(n_epoch/4) == 0:
            y_hat = np.dot(X,w)+b
            utilitaires4.plot(X[:,0], y, y_hat)
            
            print "époque #%d" % (i+1)
            print np.dot(X, w)
            print "erreur quadratique = %f" % (np.sum((y-y_hat)**2)/float(X.shape[0]))

    end = time.clock()

    print "L'entraînement a pris %f seconds (%d exemples visité par seconde)" % (end-start, (n_epoch*X.shape[0])/float(end-start))
        
    return w, b

# %%
X, y = utilitaires4.fonction_2()

X = polynomes(X,p=3)

w, b = apprend_par_batch_multi_dim(X, y, n_epoch=100000, learning_rate=0.1)

plt.clf()

print "w=%s, b=%f" % (str(w), b)
# Out:
# époque #1
# [ 0.         -0.00016124 -0.00032326 -0.00048606 -0.00064967 -0.00081407
#  -0.00097929 -0.00114531 -0.00131216 -0.00147984 -0.00164835 -0.0018177
#  -0.0019879  -0.00215895 -0.00233087 -0.00250365 -0.0026773  -0.00285183
#  -0.00302724 -0.00320355 -0.00338076 -0.00355888 -0.0037379  -0.00391784
#  -0.00409871 -0.00428051 -0.00446325 -0.00464693 -0.00483156 -0.00501715
#  -0.0052037  -0.00539123 -0.00557973 -0.00576921 -0.00595968 -0.00615115
#  -0.00634362 -0.0065371  -0.00673159 -0.00692711 -0.00712366 -0.00732124
#  -0.00751986 -0.00771953 -0.00792025 -0.00812203 -0.00832488 -0.00852881
#  -0.00873381 -0.0089399  -0.00914709 -0.00935537 -0.00956476 -0.00977527
#  -0.00998689 -0.01019964 -0.01041351 -0.01062853 -0.0108447  -0.01106201
#  -0.01128048 -0.01150012 -0.01172092 -0.01194291 -0.01216608 -0.01239043
#  -0.01261599 -0.01284275 -0.01307072 -0.0132999  -0.01353031 -0.01376194
#  -0.01399481 -0.01422893 -0.01446429 -0.0147009  -0.01493878 -0.01517793
#  -0.01541835 -0.01566005 -0.01590304 -0.01614732 -0.0163929  -0.01663979
#  -0.016888   -0.01713752 -0.01738837 -0.01764055 -0.01789407 -0.01814894
#  -0.01840516 -0.01866273 -0.01892167 -0.01918199 -0.01944368 -0.01970676
#  -0.01997122 -0.02023709 -0.02050436 -0.02077303 -0.02104313 -0.02131465
#  -0.0215876  -0.02186198 -0.02213781 -0.02241509 -0.02269382 -0.02297402
#  -0.02325568 -0.02353882 -0.02382344 -0.02410955 -0.02439715 -0.02468625
#  -0.02497687 -0.02526899 -0.02556264 -0.02585781 -0.02615452 -0.02645276
#  -0.02675256 -0.0270539  -0.02735681 -0.02766128 -0.02796732 -0.02827494
#  -0.02858415 -0.02889495 -0.02920734 -0.02952134 -0.02983696 -0.03015419
#  -0.03047304 -0.03079352 -0.03111564 -0.03143941 -0.03176482 -0.0320919
#  -0.03242063 -0.03275103 -0.03308311 -0.03341688 -0.03375233 -0.03408947
#  -0.03442832 -0.03476888 -0.03511115 -0.03545514 -0.03580086 -0.03614831
#  -0.03649751 -0.03684845 -0.03720114 -0.0375556  -0.03791182 -0.03826981
#  -0.03862959 -0.03899115 -0.0393545  -0.03971965 -0.04008661 -0.04045538
#  -0.04082596 -0.04119837 -0.04157262 -0.0419487  -0.04232662 -0.0427064
#  -0.04308803 -0.04347153 -0.04385689 -0.04424413 -0.04463326 -0.04502428
#  -0.04541719 -0.045812   -0.04620872 -0.04660736 -0.04700792 -0.04741041
#  -0.04781484 -0.0482212  -0.04862951 -0.04903978 -0.04945201 -0.0498662
#  -0.05028237 -0.05070052 -0.05112066 -0.05154278 -0.05196691 -0.05239305
#  -0.05282119 -0.05325136 -0.05368355 -0.05411778 -0.05455404 -0.05499234
#  -0.0554327  -0.05587512 -0.0563196  -0.05676615 -0.05721478 -0.05766549
#  -0.05811829 -0.05857319 -0.0590302  -0.05948931 -0.05995054 -0.06041389
#  -0.06087937 -0.06134699 -0.06181674 -0.06228865 -0.06276271 -0.06323893
#  -0.06371733 -0.06419789 -0.06468064 -0.06516557 -0.0656527  -0.06614203
#  -0.06663356 -0.06712731 -0.06762328 -0.06812147 -0.0686219  -0.06912456
#  -0.06962948 -0.07013664 -0.07064606 -0.07115775 -0.07167171 -0.07218795
#  -0.07270647 -0.07322728 -0.07375039 -0.0742758  -0.07480353 -0.07533357
#  -0.07586594 -0.07640063 -0.07693766 -0.07747703 -0.07801876 -0.07856284
#  -0.07910928 -0.07965809 -0.08020927 -0.08076284]
# erreur quadratique = 0.163116
# époque #25001
# [ 0.          0.00528095  0.01050023  0.01565831  0.02075568  0.02579282
#   0.0307702   0.03568832  0.04054765  0.04534868  0.05009188  0.05477775
#   0.05940675  0.06397938  0.06849611  0.07295743  0.07736382  0.08171576
#   0.08601373  0.09025821  0.09444969  0.09858864  0.10267556  0.10671092
#   0.1106952   0.11462888  0.11851245  0.12234639  0.12613118  0.1298673
#   0.13355524  0.13719547  0.14078848  0.14433475  0.14783476  0.15128899
#   0.15469793  0.15806205  0.16138184  0.16465778  0.16789036  0.17108005
#   0.17422733  0.17733269  0.18039661  0.18341958  0.18640206  0.18934455
#   0.19224753  0.19511148  0.19793687  0.2007242   0.20347394  0.20618658
#   0.2088626   0.21150247  0.21410669  0.21667573  0.21921007  0.22171021
#   0.22417661  0.22660976  0.22901014  0.23137824  0.23371453  0.2360195
#   0.23829363  0.2405374   0.2427513   0.2449358   0.24709138  0.24921854
#   0.25131775  0.25338948  0.25543424  0.25745248  0.25944471  0.2614114
#   0.26335302  0.26527007  0.26716303  0.26903237  0.27087858  0.27270215
#   0.27450354  0.27628325  0.27804175  0.27977954  0.28149708  0.28319486
#   0.28487337  0.28653308  0.28817448  0.28979805  0.29140427  0.29299362
#   0.29456658  0.29612365  0.29766528  0.29919198  0.30070422  0.30220249
#   0.30368726  0.30515902  0.30661824  0.30806542  0.30950103  0.31092555
#   0.31233947  0.31374327  0.31513742  0.31652242  0.31789875  0.31926687
#   0.32062729  0.32198047  0.32332691  0.32466707  0.32600146  0.32733053
#   0.32865479  0.32997471  0.33129076  0.33260344  0.33391323  0.3352206
#   0.33652605  0.33783004  0.33913307  0.34043561  0.34173815  0.34304116
#   0.34434514  0.34565055  0.3469579   0.34826764  0.34958028  0.35089628
#   0.35221613  0.35354032  0.35486932  0.35620362  0.35754369  0.35889003
#   0.36024311  0.36160341  0.36297141  0.36434761  0.36573247  0.36712649
#   0.36853013  0.36994389  0.37136825  0.37280369  0.37425069  0.37570972
#   0.37718129  0.37866586  0.38016391  0.38167594  0.38320241  0.38474382
#   0.38630064  0.38787336  0.38946246  0.39106842  0.39269172  0.39433285
#   0.39599228  0.39767049  0.39936798  0.40108522  0.40282269  0.40458088
#   0.40636026  0.40816132  0.40998454  0.4118304   0.41369939  0.41559198
#   0.41750866  0.41944991  0.42141621  0.42340805  0.4254259   0.42747024
#   0.42954157  0.43164035  0.43376708  0.43592223  0.43810629  0.44031973
#   0.44256304  0.44483671  0.44714121  0.44947702  0.45184463  0.45424452
#   0.45667717  0.45914306  0.46164267  0.46417649  0.466745    0.46934868
#   0.47198801  0.47466347  0.47737555  0.48012472  0.48291148  0.48573629
#   0.48859965  0.49150203  0.49444391  0.49742579  0.50044813  0.50351142
#   0.50661615  0.50976279  0.51295183  0.51618375  0.51945903  0.52277815
#   0.5261416   0.52954985  0.53300339  0.5365027   0.54004826  0.54364056
#   0.54728007  0.55096727  0.55470266  0.5584867   0.56231989  0.5662027
#   0.57013562  0.57411913  0.57815371  0.58223983  0.58637799  0.59056867
#   0.59481234  0.5991095   0.60346061  0.60786616  0.61232664  0.61684253
#   0.6214143   0.62604245  0.63072744  0.63546977]
# erreur quadratique = 0.003281
# époque #50001
# [ 0.          0.00736623  0.01463032  0.02179307  0.02885529  0.03581776
#   0.0426813   0.0494467   0.05611476  0.0626863   0.0691621   0.07554297
#   0.08182972  0.08802313  0.09412402  0.10013318  0.10605142  0.11187953
#   0.11761833  0.1232686   0.12883115  0.13430679  0.13969631  0.14500051
#   0.1502202   0.15535617  0.16040924  0.16538019  0.17026983  0.17507897
#   0.1798084   0.18445892  0.18903134  0.19352645  0.19794506  0.20228797
#   0.20655599  0.2107499   0.21487052  0.21891864  0.22289506  0.2268006
#   0.23063604  0.23440219  0.23809985  0.24172982  0.24529291  0.24878991
#   0.25222162  0.25558885  0.2588924   0.26213307  0.26531166  0.26842897
#   0.2714858   0.27448295  0.27742124  0.28030144  0.28312438  0.28589085
#   0.28860164  0.29125757  0.29385943  0.29640802  0.29890415  0.30134861
#   0.30374221  0.30608575  0.30838004  0.31062586  0.31282402  0.31497533
#   0.31708059  0.31914059  0.32115613  0.32312803  0.32505708  0.32694408
#   0.32878983  0.33059513  0.33236079  0.3340876   0.33577638  0.33742791
#   0.339043    0.34062245  0.34216707  0.34367764  0.34515499  0.3465999
#   0.34801317  0.34939562  0.35074803  0.35207122  0.35336598  0.35463311
#   0.35587342  0.3570877   0.35827676  0.3594414   0.36058242  0.36170062
#   0.3627968   0.36387176  0.36492631  0.36596125  0.36697737  0.36797548
#   0.36895638  0.36992087  0.37086976  0.37180383  0.3727239   0.37363077
#   0.37452524  0.3754081   0.37628016  0.37714222  0.37799509  0.37883956
#   0.37967643  0.38050651  0.3813306   0.38214949  0.38296399  0.38377491
#   0.38458303  0.38538917  0.38619413  0.38699869  0.38780368  0.38860988
#   0.38941811  0.39022915  0.39104382  0.39186291  0.39268722  0.39351756
#   0.39435473  0.39519952  0.39605274  0.3969152   0.39778768  0.398671
#   0.39956595  0.40047334  0.40139396  0.40232863  0.40327813  0.40424327
#   0.40522485  0.40622368  0.40724055  0.40827627  0.40933163  0.41040744
#   0.4115045   0.41262361  0.41376557  0.41493119  0.41612125  0.41733658
#   0.41857796  0.4198462   0.42114209  0.42246645  0.42382007  0.42520375
#   0.4266183   0.42806451  0.42954318  0.43105513  0.43260114  0.43418203
#   0.43579858  0.43745161  0.43914191  0.44087029  0.44263754  0.44444447
#   0.44629188  0.44818057  0.45011134  0.45208499  0.45410233  0.45616415
#   0.45827126  0.46042445  0.46262454  0.46487231  0.46716858  0.46951414
#   0.47190979  0.47435633  0.47685458  0.47940532  0.48200935  0.48466749
#   0.48738053  0.49014927  0.49297452  0.49585707  0.49879773  0.50179729
#   0.50485656  0.50797634  0.51115744  0.51440064  0.51770676  0.52107659
#   0.52451094  0.52801061  0.5315764   0.5352091   0.53890953  0.54267847
#   0.54651674  0.55042514  0.55440446  0.55845551  0.56257909  0.56677599
#   0.57104703  0.575393    0.5798147   0.58431294  0.58888851  0.59354222
#   0.59827487  0.60308726  0.60798019  0.61295446  0.61801087  0.62315023
#   0.62837334  0.63368099  0.63907399  0.64455313  0.65011923  0.65577308
#   0.66151549  0.66734725  0.67326916  0.67928203  0.68538666  0.69158385
#   0.6978744   0.70425911  0.71073878  0.71731422]
# erreur quadratique = 0.002240
# époque #75001
# [ 0.          0.00863698  0.01714716  0.02553154  0.0337911   0.04192686
#   0.0499398   0.05783091  0.0656012   0.07325167  0.0807833   0.08819709
#   0.09549404  0.10267515  0.1097414   0.11669381  0.12353335  0.13026103
#   0.13687785  0.1433848   0.14978287  0.15607306  0.16225637  0.1683338
#   0.17430633  0.18017497  0.18594071  0.19160455  0.19716748  0.2026305
#   0.2079946   0.21326078  0.21843004  0.22350337  0.22848177  0.23336624
#   0.23815776  0.24285734  0.24746597  0.25198465  0.25641437  0.26075613
#   0.26501093  0.26917976  0.27326361  0.27726349  0.28118039  0.2850153
#   0.28876922  0.29244315  0.29603808  0.29955501  0.30299493  0.30635884
#   0.30964774  0.31286262  0.31600448  0.31907431  0.32207311  0.32500187
#   0.3278616   0.33065328  0.33337792  0.33603651  0.33863004  0.34115951
#   0.34362591  0.34603025  0.34837352  0.35065671  0.35288082  0.35504685
#   0.35715579  0.35920864  0.36120639  0.36315004  0.36504059  0.36687902
#   0.36866635  0.37040355  0.37209164  0.3737316   0.37532443  0.37687113
#   0.37837269  0.37983011  0.38124438  0.3826165   0.38394747  0.38523828
#   0.38648993  0.38770341  0.38887972  0.39001986  0.39112481  0.39219559
#   0.39323318  0.39423857  0.39521277  0.39615678  0.39707158  0.39795817
#   0.39881755  0.39965071  0.40045865  0.40124237  0.40200287  0.40274113
#   0.40345815  0.40415493  0.40483247  0.40549176  0.4061338   0.40675958
#   0.4073701   0.40796635  0.40854934  0.40912005  0.40967948  0.41022863
#   0.4107685   0.41130008  0.41182436  0.41234234  0.41285503  0.4133634
#   0.41386847  0.41437122  0.41487265  0.41537376  0.41587555  0.416379
#   0.41688512  0.4173949   0.41790933  0.41842942  0.41895615  0.41949053
#   0.42003355  0.42058621  0.4211495   0.42172442  0.42231196  0.42291312
#   0.42352889  0.42416028  0.42480827  0.42547387  0.42615807  0.42686186
#   0.42758624  0.42833221  0.42910076  0.42989289  0.4307096   0.43155188
#   0.43242072  0.43331712  0.43424208  0.4351966   0.43618166  0.43719827
#   0.43824743  0.43933012  0.44044734  0.44160009  0.44278937  0.44401617
#   0.44528148  0.44658631  0.44793165  0.44931849  0.45074783  0.45222066
#   0.45373799  0.45530081  0.45691011  0.45856689  0.46027215  0.46202688
#   0.46383208  0.46568874  0.46759785  0.46956043  0.47157745  0.47364992
#   0.47577884  0.47796519  0.48020998  0.4825142   0.48487884  0.48730491
#   0.48979339  0.49234529  0.4949616   0.49764332  0.50039143  0.50320695
#   0.50609085  0.50904415  0.51206783  0.51516289  0.51833033  0.52157114
#   0.52488632  0.52827687  0.53174378  0.53528804  0.53891065  0.54261262
#   0.54639492  0.55025857  0.55420455  0.55823387  0.56234751  0.56654647
#   0.57083176  0.57520436  0.57966527  0.58421549  0.58885601  0.59358783
#   0.59841194  0.60332935  0.60834104  0.61344801  0.61865127  0.62395179
#   0.62935059  0.63484865  0.64044697  0.64614656  0.65194839  0.65785348
#   0.66386281  0.66997738  0.67619818  0.68252623  0.6889625   0.69550799
#   0.7021637   0.70893064  0.71580978  0.72280213  0.72990869  0.73713045
#   0.7444684   0.75192354  0.75949687  0.76718939]
# erreur quadratique = 0.001854
# L'entraînement a pris 8.429124 seconds (2965907 exemples visité par seconde)
# w=[ 2.36117281 -4.431242    2.86765106], b=0.092697

# %% [markdown]
# Et voilà! Dans le fond, c'est pas très sorcier. On fourni au modèle $x$, $x^2$ et $x^3$. Il apprend donc directement
#
# $$ y = w_1x +w_2x^2+w_3x^3 + b$$
#
# On poussera l'idée un peu plus à la prochaine démo dans le cadre de la classification linéaire.
