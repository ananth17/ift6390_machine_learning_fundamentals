# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# %aimport numpy
np=numpy
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import cPickle
import sklearn.linear_model

# get the general utilities
import utility
reload(utility)

# preprocessing functions
import preprocessing
reload(preprocessing)

# performance measure functions
import analysis
reload(analysis)
# Out:
# <module 'analysis' from 'analysis.pyc'>

# %%
# DATA GENERATION (in case needed)
# set regenerate to True if must recreate the pkl files (it's pretty long)

regenerate = False

if (regenerate==True):
    def separate_data_per_class(data, classes):
        # will return a dict {class -> data}
        separated_data = dict()
        for i in range(0, len(classes)):
            if (classes[i] in separated_data):
                separated_data[classes[i]] = np.vstack((separated_data[classes[i]], data[i]))
            else:
                separated_data[classes[i]] = data[i]
        return separated_data

    f = open("mnist.pkl", "rb")
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y)= cPickle.load(f)
    f.close()
    
    # join the datasets into a big one
    data_x = np.vstack((np.vstack((train_x, valid_x)), test_x))
    data_y = np.hstack((np.hstack((train_y, valid_y)), test_y))
    
    
    # separate the training data per class
    all_data = separate_data_per_class(data_x, data_y)
    
    
    f = open("separated_mnist.pkl", "wb")
    cPickle.dump(all_data, f)
    f.close()
    print "regenerated data"

# %%
# GENERAL DATA SETTINGS

# load the whole dataset
f = open("separated_mnist.pkl", "rb")
mnist = cPickle.load(f)
f.close()

# set the seed
numpy.random.seed(42)

# %%
# PREPROCESSING

# deskewed and brought back to 8-bit
preprocess = lambda x: numpy.ndarray.flatten(preprocessing.to8bit(preprocessing.deskew(x)))
mnist_deskewed = {k: map(preprocess, v) for k, v in mnist.items()}

# %%
print mnist_deskewed[0]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-8ce1d8145d86> in <module>()
# ----> 1 print mnist_deskewed[0]
#
# /home/shiva/anaconda/lib/python2.7/site-packages/numpy/core/numeric.pyc in array_repr(arr, max_line_width, precision, suppress_small)
#    1651     if arr.size > 0 or arr.shape==(0,):
#    1652         lst = array2string(arr, max_line_width, precision, suppress_small,
# -> 1653                            ', ', "array(")
#    1654     else: # show zero-length shape unless it is (0,)
#    1655         lst = "[], shape=%s" % (repr(arr.shape),)
#
# /home/shiva/anaconda/lib/python2.7/site-packages/numpy/core/arrayprint.pyc in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter)
#     452     else:
#     453         lst = _array2string(a, max_line_width, precision, suppress_small,
# --> 454                             separator, prefix, formatter=formatter)
#     455     return lst
#     456
#
# /home/shiva/anaconda/lib/python2.7/site-packages/numpy/core/arrayprint.pyc in _array2string(a, max_line_width, precision, suppress_small, separator, prefix, formatter)
#     255     formatdict = {'bool' : _boolFormatter,
#     256                   'int' : IntegerFormat(data),
# --> 257                   'float' : FloatFormat(data, precision, suppress_small),
#     258                   'longfloat' : LongFloatFormat(precision),
#     259                   'complexfloat' : ComplexFormat(data, precision,
#
# /home/shiva/anaconda/lib/python2.7/site-packages/numpy/core/arrayprint.pyc in __init__(self, data, precision, suppress_small, sign)
#     539         self.max_str_len = 0
#     540         try:
# --> 541             self.fillFormat(data)
#     542         except (TypeError, NotImplementedError):
#     543             # if reduce(data) fails, this instance will not be called, just
#
# /home/shiva/anaconda/lib/python2.7/site-packages/numpy/core/arrayprint.pyc in fillFormat(self, data)
#     578             if len(non_zero):
#     579                 precision = max([_digits(x, self.precision, format)
# --> 580                                  for x in non_zero])
#     581             else:
#     582                 precision = 0
#
# /home/shiva/anaconda/lib/python2.7/site-packages/numpy/core/arrayprint.pyc in _digits(x, precision, format)
#     631
#     632 def _digits(x, precision, format):
# --> 633     s = format % x
#     634     z = s.rstrip('0')
#     635     return precision - len(s) + len(z)
#
# KeyboardInterrupt:

# %%
# 10-fold validation, 1/10 test, 9/10 train
tenfold = utility.generate_datasets(mnist_deskewed, 42)

# %%
#Preprocessing of the original MNIST data is mainly moti-
#vated by practical experience. MNIST digits are normalized
#such that the width or height of the bounding box equals
#20 pixels. The variation of the aspect ratio for various digits
#is quite large, and we normalize the width of the bounding
#box to range from 8 to 20 pixels with a step-size of 2 pixels
#prior to training for all digits except ones. This results in 7
#different training sets. Additionally, we generate a deslanted
#training set using a PCA algorithm that vertically aligns the
#principal axis of the digits. The experiments performed with
#these nine different data sets will henceforth be referred to
#as the experiments with preprocessed data.

# %%
#a = numpy.random.choice(mnist[0], (10, 784), replace=False)
train10fold = {k:v[np.random.choice(v.shape[0], int(math.floor(9.*v.shape[0]/10.)), replace=False),:] for k,v in mnist.items()}
test10fold = {k:v[np.random.choice(v.shape[0], int(math.floor(v.shape[0]/10.)), replace=False),:] for k,v in mnist.items()}

# %%
print train10fold[2].shape
print test10fold[2].shape
print mnist[2].shape
print train10fold[2].shape[0] + test10fold[2].shape[0]
#import linear_committee
#reload(linear_committee)

#construct = linear_committee.LinearCommittee(4, 'majority', 'log')
# Out:
# (6291, 784)
# (699, 784)
# (6990, 784)
# 6990

# %%
#construct.fit(0, train0, train_y)
#construct.fit(1, train1, train_y)
#construct.fit(2, train2, train_y)
#construct.fit(3, train_x, train_y)

#construct._classifiers[0].fit(train_x, train_y)
#construct._classifiers[1].fit(deskewed_train, train_y)

#print get_global_accuracy(train0, train_y, construct._classifiers[0])
#print get_global_accuracy(train1, train_y, construct._classifiers[1])
#print get_global_accuracy(train2, train_y, construct._classifiers[2])
#print get_global_accuracy(train_x, train_y, construct._classifiers[3])
# Out:
# 0.93574
# 0.9341
# 0.89462
# 0.89552

# %%
data = zip(train0, train1, train2, train_x)

# %%
assert_legit_mnist(to8bit(train0[1]))
# Out:
# True

# %%
result = []
for i in range(0, len(data)):
    vote = construct.vote(data[i])
    result.append(vote==train_y[i])
print np.sum(result) / float(len(result))

# %%
# Out:
# 0.93026

# %%
# initialize the model
lin_classifier = sklearn.linear_model.SGDClassifier()

# %%
# train the model
lin_classifier.fit(train_x, train_y)
# Out:
# SGDClassifier(alpha=0.0001, class_weight=None, epsilon=0.1, eta0=0.0,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='optimal',
#        loss='hinge', n_iter=5, n_jobs=1, penalty='l2', power_t=0.5,
#        random_state=None, shuffle=False, verbose=0, warm_start=False)

# %%
print get_global_accuracy(train_x, train_y, lin_classifier)
print get_global_accuracy(test_x, test_y, lin_classifier)
# Out:
# 0.88928
# 0.8877

# %%
train_classification_performance = get_class_based_performance(train_data, lin_classifier)
test_classification_performance = get_class_based_performance(test_data, lin_classifier)

train_confusion_matrix = confusion_matrix(train_classification_performance[1], "classifications in training set")
#test_heatmap  = heatmap_classification(test_classification, "classification in test set")

# %%
from distortion import distort_random
c1=8
target = 5
digit_index = 200

digit = train_data[c1][digit_index]
show_mnist_digit(digit)

dists = []
for i in range(0, 1000):
    dists.append(distort_random(digit, c1, target, lin_classifier, seed=i))

distances = map(lambda x: np.dot(x, x), dists)
best_index = np.argmin(distances)

show_mnist_digit(dists[best_index] + digit)
print "at a distance of " + str(distances[best_index])
# Out:
# at a distance of 1.10723876953

# %%
show_mnist_digit(train_data[c1][0])

# %%
import distortion
reload(distortion)

c1 = 1
imIndx = 0
digit = train_data[c1][imIndx]
getIm = True

show_mnist_digit(digit)
#dist = distortion.disto

for target in range(0, 10):
    if c1 == target:
        continue
    else:
        print "TARGET " + str(target)

        dist = distortion.distort_opt_ratio(digit, c1, target, lin_classifier, get_image=getIm)
        if getIm:
            show_mnist_digit(digit+dist)
            print np.dot(dist, dist)
            print "classified as " + str(lin_classifier.predict(digit + dist)[0])
        else:
            print dist

        print
        print
print distortion.get_squared_norm_adversarial(digit, c1, lin_classifier)
# Out:
# TARGET 0
# 2.73416137695
# classified as 2
#
#
# TARGET 2
# 0.341812133789
# classified as 2
#
#
# TARGET 3
# 0.788070678711
# classified as 3
#
#
# TARGET 4
# 1.55676269531
# classified as 4
#
#
# TARGET 5
# 0.771697998047
# classified as 5
#
#
# TARGET 6
# 2.73222351074
# classified as 6
#
#
# TARGET 7
# 1.11317443848
# classified as 7
#
#
# TARGET 8
# 0.234161376953
# classified as 8
#
#
# TARGET 9
# 1.22552490234
# classified as 9
#
#
# 0.234161376953

# %%
import time
reload(distortion)
distances = []
c1 = 0
t0 = time.time()
for digit in train_data[c1][0:100]:
    if lin_classifier.predict(digit) == c1:
        distances.append(distortion.get_squared_norm_adversarial(digit, c1, lin_classifier))
t1 = time.time()
print "done in " + str(t1 - t0)
# Out:
# done in 89.9788000584

# %%
print "done"
# Out:
# done

# %%
plt.plot(distances)
plt.show()
plt.plot(sorted(distances))
plt.show()
well_classified = []
not_well_classified = []
index=0
for digit in train_data[c1][0:100]:
    if lin_classifier.predict(digit)==c1:
        well_classified.append((digit, distances[index]))
        index+=1
    else:
        not_well_classified.append(digit)
well_classified.sort(key=lambda x: x[1])

print len(well_classified)
for i in range(0, 20):
    show_mnist_digit(well_classified[-i-1][0])

# when you see the images, you imagine it's possible
# that this could be used to evaluate
# preprocessing schemes

print "\n\nNOT WELL CLASSIFIED"
for i in range(0, 20):
    show_mnist_digit(not_well_classified[i])
# Out:
# 99
# NOT WELL CLASSIFIED
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-29ebee0710cb> in <module>()
#      24 print "\n\nNOT WELL CLASSIFIED"
#      25 for i in range(0, 20):
# ---> 26     show_mnist_digit(not_well_classified[i])
#
# IndexError: list index out of range

# %%
# could use the gaussian filters to bring explicit locality
# to the linear regression classifier (convnet fashion) with
# overlapping perceptual windows...
#import scipy.ndimage
# let's apply gaussian filter on the coefficients and examinate the classification rate afterwards
#for i in range(0, 10):
#    lin_classifier2.coef_[i] = np.ndarray.flatten(scipy.ndimage.gaussian_filter(np.reshape(np.copy(lin_classifier.coef_[i]), (28, 28)), 1))
    
   
#show_coefficients(lin_classifier.coef_)
