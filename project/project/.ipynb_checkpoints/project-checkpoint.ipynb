# %% [markdown]
# # Messing with classifiers
# ### IFT6390, Gabriel C-Parent and Dora Fugère

# %% [markdown]
# #### Abstract

# %% [markdown]
# ## Modules

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# %aimport numpy
np=numpy
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import cPickle
import sklearn.linear_model
import sklearn.datasets
import sklearn.cross_validation  # we'll use stratified kfold

# get the general utilities
import utility
reload(utility)

# preprocessing functions
import preprocessing
reload(preprocessing)

# performance measure functions
import analysis
reload(analysis)

# better print function
from __future__ import print_function

# plotting functions
import seaborn

# cython performance
import pyximport; pyximport.install(reload_support=True)
# Out:
# (None, <pyximport.pyximport.PyxImporter at 0x7fdb4b52ced0>)

# %% [markdown]
# ## Data loading

# %%
# GENERAL DATA HANDLING

# load the mnist dataset
mnist = sklearn.datasets.fetch_mldata('MNIST original', data_home='.')
mnist.data = map(lambda x: x / 256., mnist.data)  # bring to float


# preprocessing (deskew and to 8-bit)
preprocess = lambda x: preprocessing.to8bit(preprocessing.deskew(x))
mnist.data = np.reshape(map(preprocess, mnist.data), (len(mnist.data), 784))

# %% [markdown]
# # Experiment 1
# verify that the size of the interval on the true value of $\lVert{r} \rVert^2$ is always small
#
# to assess that, we make sure that the relative size of the interval to the distance calculated is small

# %%
# generate the data
train_x, test_x, train_y, test_y = \
            sklearn.cross_validation.train_test_split(mnist.data,
                                                      mnist.target,
                                                      train_size=int(6.*len(mnist.target)/7.),
                                                      random_state=1)
train_x = np.reshape(train_x, (len(train_x), 784))
test_x = np.reshape(test_x, (len(test_x), 784))

# train the classifiers
reg = ['l2', 'l1', 'elasticnet']
classifiers = [sklearn.linear_model.SGDClassifier(loss='hinge', penalty=r, alpha=0.001) for r in reg] # initialize the linear svm
map(lambda x: x.fit(train_x, train_y), classifiers)

# check the accuracy of the classifiers
map(lambda x: print("precision = " + str(analysis.get_global_accuracy(test_x, test_y, x))), classifiers)
# Out:
# precision = 0.9405
# precision = 0.9257
# precision = 0.9391
# [None, None, None]

# %%
import distortion
reload(distortion)

# we'll use 1000 different images from the training set
size = 200
np.random.seed(42)
indices = np.random.choice(np.arange(0, len(train_y)), size*3)

intervals = []
for classifier in classifiers:
    interval = []
    adequate = 0
    for index in indices:
        original_class = train_y[index]
        digit = train_x[index]
        if classifier.predict(digit) == original_class:
            adequate += 1
            v = distortion.get_squared_norm_adversarial(digit, original_class, classifier)
            interval.append(v)
        if adequate >= size:
            break
    intervals.append(interval)

# %%
# PLOT
# experiment 1

palette = seaborn.hls_palette(8, l=.3, s=.8)
color_dict = {'l1':palette[1], 'l2':palette[2], 'elasticnet':palette[0]}
seaborn.set(style="white")

interval_rel = []
for i in intervals:
    tmp = []
    for j in i:
        tmp.append(j[1] - j[0])
    interval_rel.append(tmp)


names = [u'{1}\nα ={0}'.format(c.alpha, c.penalty) for c in classifiers]
seaborn.boxplot(interval_rel, color=[color_dict[i] for i in reg], names=names)
#plt.title("interval width of the squared norm for different classifiers, n={0}".format(len(interval_rel[0])))
plt.ylabel("interval width around squared norm")
plt.xlabel("classifier penalty types and weight, n = {0}".format(len(interval_rel[0])))
savefig('../figs/experiment1.eps')

# %% [markdown]
# This demonstrates that our heuristic is acceptable (the interval is relatively very small to the expected value).

# %% [markdown]
# # Experiment 2

# %% [markdown]
# We'd like to investigate the relation with various regularization methods and parameters (we always use hinge loss).

# %%
# generate the data
train_x, test_x, train_y, test_y = \
            sklearn.cross_validation.train_test_split(mnist.data,
                                                      mnist.target,
                                                      train_size=int(6.*len(mnist.target)/7.),
                                                      random_state=1)
train_x = np.reshape(train_x, (len(train_x), 784))
test_x = np.reshape(test_x, (len(test_x), 784))

# %%
# initialize the l1 and l2 classifiers
penalties = ['l2', 'l1', 'elasticnet']
alphas = [0.0000000000001, 0.0001, 0.001, 0.1, 0.5]
classifiers_l1 = [sklearn.linear_model.SGDClassifier(loss='hinge', penalty='l1', alpha=a) for a in alphas]
classifiers_l2 = [sklearn.linear_model.SGDClassifier(loss='hinge', penalty='l2', alpha=a) for a in alphas]


# initialize the elasticnet classifiers
classifiers_015 = [sklearn.linear_model.SGDClassifier(loss='hinge', penalty='elasticnet', l1_ratio=0.15, alpha=a) for a in alphas]
classifiers_05 = [sklearn.linear_model.SGDClassifier(loss='hinge', penalty='elasticnet', l1_ratio=0.5, alpha=a) for a in alphas]
classifiers_085 = [sklearn.linear_model.SGDClassifier(loss='hinge', penalty='elasticnet', l1_ratio=0.85, alpha=a) for a in alphas]

# %%
# train all the classifiers
acceptable_classifiers = []

for classifier in (classifiers_l1 + classifiers_l2 + classifiers_015 + classifiers_05 + classifiers_085):
    # 
    classifier.fit(train_x, train_y)
    score = classifier.score(test_x, test_y)
    if score > 0.85:
        #print("classifier {0} is good".format(i))
        acceptable_classifiers.append(classifier)

# %%
import pyximport; pyximport.install(reload_support=True)
import distortion_fast
reload(distortion_fast)

classifier = acceptable_classifiers[0]
index = 4
print(distortion_fast.get_distance_and_class(train_x[index], train_y[index], classifier))

utility.show_mnist_digit(train_x[index])
# Out:
# (6, 0.1967010498046875)

# %%
import pyximport; pyximport.install(reload_support=True)
import distortion_fast
reload(distortion_fast)

# train l2 classifier
classifier = sklearn.linear_model.SGDClassifier(penalty='l2', alpha=0.5)
classifier.fit(train_x, train_y)


# we'll use 1000 different images from the training set
num_per_class = 1000  # total of 300 images, 30 per class

# set the seed
np.random.seed(42)
indices = np.random.choice(np.arange(0, len(mnist.target)), len(mnist.target))


num_done = np.zeros(10)
index = 0
res_per_class = dict()
destinations = numpy.zeros((10, 10))

for i in range(0, 10):
    res_per_class[i] = []

while np.sum(num_done) < num_per_class * 10:
    # iterate
        
    # figure out the original class
    scramble_index = indices[index]
    original_class = mnist.target[scramble_index]
    digit = mnist.data[scramble_index]
    # check if need more of the specific class
    if num_done[original_class] < num_per_class:
        # we will check if the class matches
        predicted_class = classifier.predict(digit)
        
        if predicted_class == original_class:
            # update the count
            num_done[original_class] += 1
                
            # we'll add the observation
            distance_and_class = distortion_fast.get_distance_and_class(digit, original_class, classifier)
            res_per_class[original_class].append(distance_and_class)
            destinations[int(original_class)][int(distance_and_class[0])] += 1
    index += 1

# %%
seaborn.set_context("paper")
plt.figure(figsize=(10,8))

seaborn.heatmap(destinations, annot=True)
plt.ylabel("original class")
plt.xlabel("distorted to class")
plt.savefig("../figs/experiment_3.eps")
plt.show()

# %%
seaborn.set_context("paper")
plt.figure(figsize=(10,8))

acc1 = analysis.get_class_performance(train_x, train_y, classifier)
seaborn.heatmap(acc1, annot=True)
plt.ylabel("correct class")
plt.xlabel("predicted class")
plt.show()

# %%
palette = seaborn.hls_palette(8, l=.3, s=.8)
color_dict = {'l1':palette[1], 'l2':palette[2], 'elasticnet':palette[0]}
seaborn.set(style="white")

names = []
color = []
scores = []
for classifier in acceptable_classifiers:
   # print(classifier)
    p = classifier.penalty
    score = classifier.score(test_x, test_y)
    a = classifier.alpha
    color.append(color_dict[p])
    scores.append(score)
    if p=='l1':
        names.append(u'{0}\nα ={1}\n% = {2}'.format(p, a, score))
    elif p=='l2':
        names.append(u'{0}\nα ={1}\n% = {2}'.format(p, a, score))
    else:
        names.append(u'{0}\nα ={1}\nr = {2}\n% = {3}'.format(p, a, classifier.l1_ratio, score))


# create the plots
seaborn.set_style("white")

# plot
#fig, ax1 = plt.subplots(figsize=(15,10))
plt.figure(figsize=(20, 10))
plt.title("regularization (n={0})".format(len(squared_norms[0])))
plt.ylabel("squared euclidian norm to adversarial example")
plt.xlabel("classifiers and training parameters")
seaborn.boxplot(squared_norms, color=color, names=names)

#xs = np.arange(1, len(names)+1)

#ax2 = ax1.twinx()
#ax2.plot(xs, scores, linestyle='None', marker='_')
#ax2.set_ylabel('accuracy of generalization')
savefig("../figs/experiment_2.eps")
plt.show()

# %%
print(bound)
print(len(data_l1))
print(len(data_l1[2]))
# Out:
# 145
# 3
# 139

# %%
# initialize the model
lin_classifier = sklearn.linear_model.SGDClassifier()

# %%
# train the model
lin_classifier.fit(train_x, train_y)
# Out:
# SGDClassifier(alpha=0.0001, class_weight=None, epsilon=0.1, eta0=0.0,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='optimal',
#        loss='hinge', n_iter=5, n_jobs=1, penalty='l2', power_t=0.5,
#        random_state=None, shuffle=False, verbose=0, warm_start=False)

# %%
print analysis.get_global_accuracy(train_x, train_y, lin_classifier)
print analysis.get_global_accuracy(test_x, test_y, lin_classifier)
# Out:
# 0.937
# 0.9283

# %%
import pyximport; pyximport.install(reload_support=True)
import distortion_fast
reload(distortion_fast)


index = 2
digit = train_x[index]
c1 = train_y[index]
getIm = False

utility.show_mnist_digit(digit)
#dist = distortion.disto

for target in range(0, 10):
    if c1 == target:
        continue
    else:
        print "TARGET " + str(target)

        dist = distortion.distort_opt_ratio(digit, c1, target, lin_classifier, get_image=getIm)
        if getIm:
            utility.show_mnist_digit(digit+dist)
            print np.dot(dist, dist)
            print "classified as " + str(lin_classifier.predict(digit + dist)[0])
        else:
            print dist

        print
        print
print distortion.get_squared_norm_adversarial(digit, c1, lin_classifier)
# Out:
# TARGET 1
# (2.20391845703125, 2.2046966552734375)
# TARGET 2
# (1.1251373291015625, 1.125640869140625)
# TARGET 3
# (0.775787353515625, 0.7761383056640625)
# TARGET 4
# (1.417266845703125, 1.4182891845703125)
# TARGET 5
# (0.420806884765625, 0.4213104248046875)
#
#
# TARGET 6
# (1.344482421875, 1.3455047607421875)
# TARGET 7
# (2.6116180419921875, 2.612701416015625)
# TARGET 8
# (1.2751617431640625, 1.275604248046875)
# TARGET 9
# (1.6295928955078125, 1.629791259765625)
# inf

# %%
classifier = sklearn.linear_model.SGDClassifier()
classifier.fit(train_x, train_y)
# Out:
# SGDClassifier(alpha=0.0001, class_weight=None, epsilon=0.1, eta0=0.0,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='optimal',
#        loss='hinge', n_iter=5, n_jobs=1, penalty='l2', power_t=0.5,
#        random_state=None, shuffle=False, verbose=0, warm_start=False)

# %%
import cython
import pyximport; pyximport.install(reload_support=True)
import distortion_fast
reload(distortion_fast)

import distortion
reload(distortion)

coefs = classifier.coef_

for i in range(0, 10):
    digit = train_x[i]
    #utility.show_mnist_digit(digit)
    pred = classifier.predict(digit)[0]
    if pred == train_y[i]:
        # well classified
        print()
        c1 = train_y[i]
        c2 = np.random.choice(np.delete(np.arange(0, 10), train_y[i]))
        
        # %time print(distortion_fast.get_distance(digit, c1, classifier))
        # %time print(distortion.get_dist_fast(digit, c1, classifier))
# Out:
# 0.979461669922
# CPU times: user 75.4 ms, sys: 0 ns, total: 75.4 ms
# Wall time: 75.3 ms
# 0.979461669922
# CPU times: user 469 ms, sys: 11.9 ms, total: 481 ms
# Wall time: 482 ms
#
# 0.250106811523
# CPU times: user 47.8 ms, sys: 0 ns, total: 47.8 ms
# Wall time: 47.9 ms
# 0.250106811523
# CPU times: user 323 ms, sys: 0 ns, total: 323 ms
# Wall time: 324 ms
#
# 0.421310424805
# CPU times: user 52 ms, sys: 0 ns, total: 52 ms
# Wall time: 52.2 ms
# 0.421310424805
# CPU times: user 331 ms, sys: 3.89 ms, total: 335 ms
# Wall time: 338 ms
#
# 0.522750854492
# CPU times: user 54 ms, sys: 0 ns, total: 54 ms
# Wall time: 54 ms
# 0.522750854492
# CPU times: user 332 ms, sys: 3.97 ms, total: 336 ms
# Wall time: 337 ms
#
# 0.312850952148
# CPU times: user 45.5 ms, sys: 0 ns, total: 45.5 ms
# Wall time: 45.6 ms
# 0.312850952148
# CPU times: user 286 ms, sys: 4 ms, total: 290 ms
# Wall time: 288 ms
#
# 0.734069824219
# CPU times: user 62.1 ms, sys: 41 µs, total: 62.2 ms
# Wall time: 62.3 ms
# 0.734069824219
# CPU times: user 353 ms, sys: 0 ns, total: 353 ms
# Wall time: 354 ms
#
# 0.00331115722656
# CPU times: user 31.4 ms, sys: 0 ns, total: 31.4 ms
# Wall time: 31.5 ms
# 0.00331115722656
# CPU times: user 254 ms, sys: 3.93 ms, total: 258 ms
# Wall time: 259 ms
#
# 0.0765228271484
# CPU times: user 45.9 ms, sys: 0 ns, total: 45.9 ms
# Wall time: 45.9 ms
# 0.0765228271484
# CPU times: user 261 ms, sys: 0 ns, total: 261 ms
# Wall time: 262 ms
#
# 0.0236663818359
# CPU times: user 26.4 ms, sys: 0 ns, total: 26.4 ms
# Wall time: 26.5 ms
# 0.0236663818359
# CPU times: user 225 ms, sys: 3.93 ms, total: 229 ms
# Wall time: 230 ms
#
# 0.532760620117
# CPU times: user 54.1 ms, sys: 0 ns, total: 54.1 ms
# Wall time: 54.1 ms
# 0.532760620117
# CPU times: user 354 ms, sys: 0 ns, total: 354 ms
# Wall time: 356 ms
